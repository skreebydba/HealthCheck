# %% [markdown]
# # Chapter 1

# %% [markdown]
# # Get Database Info
# This code returns information about databases on an instance of SQL Server.

# %%
$instances = Get-Content -Path C:\Users\fgill\Documents\GitHub\AzureDataStudioAndContainers\instances.txt;

foreach($instance in $instances)
{
    Get-DbaDatabase -SqlInstance $instance | Select-Object -Property SqlInstance, Name, ID, SizeMB, DataSpaceUsage, IndexSpaceUsage, CreateDate,Compatibility, LogReuseWaitStatus, Owner, PageVerify, RecoveryModel, DatabaseEngineEdition, LastFullBackup, LastDiffBackup, LastLogBackup, AutoClose, AutoShrink, Collation,  DefaultFileGroup, DefaultSchema, HasMemoryOptimizedObjects, IsReadCommittedSnapshotOn;
}
# Out:
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : master
# ID                        : 1
# SizeMB                    : 377.8125
# DataSpaceUsage            : 357496
# IndexSpaceUsage           : 2968
# CreateDate                : 4/8/2003 9:13:36 AM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/9/2020 12:00:02 AM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : tempdb
# ID                        : 2
# SizeMB                    : 200
# DataSpaceUsage            : 1280
# IndexSpaceUsage           : 1512
# CreateDate                : 7/30/2020 11:24:45 AM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Simple
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 1/1/0001 12:00:00 AM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : model
# ID                        : 3
# SizeMB                    : 16
# DataSpaceUsage            : 1088
# IndexSpaceUsage           : 1224
# CreateDate                : 4/8/2003 9:13:36 AM
# Compatibility             : Version140
# LogReuseWaitStatus        : LogBackup
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/9/2020 12:00:03 AM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : msdb
# ID                        : 4
# SizeMB                    : 1506
# DataSpaceUsage            : 498808
# IndexSpaceUsage           : 69312
# CreateDate                : 8/22/2017 7:39:22 PM
# Compatibility             : Version140
# LogReuseWaitStatus        : LogBackup
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/9/2020 12:00:04 AM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : AdventureWorks2014
# ID                        : 5
# SizeMB                    : 271.25
# DataSpaceUsage            : 109496
# IndexSpaceUsage           : 88264
# CreateDate                : 9/20/2019 11:14:36 AM
# Compatibility             : Version120
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Simple
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:42:48 PM
# LastDiffBackup            : 8/17/2020 9:30:33 AM
# LastLogBackup             : 3/9/2020 4:30:01 PM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : auditdb
# ID                        : 6
# SizeMB                    : 16
# DataSpaceUsage            : 1112
# IndexSpaceUsage           : 1232
# CreateDate                : 2/19/2020 2:39:22 PM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : SaXeventTest
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:42:49 PM
# LastDiffBackup            : 8/17/2020 9:30:34 AM
# LastLogBackup             : 8/17/2020 10:30:01 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : Baselines
# ID                        : 7
# SizeMB                    : 256
# DataSpaceUsage            : 2048
# IndexSpaceUsage           : 1408
# CreateDate                : 2/25/2020 12:20:21 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:42:50 PM
# LastDiffBackup            : 8/17/2020 9:30:35 AM
# LastLogBackup             : 8/17/2020 10:30:02 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : WideWorldImporters
# ID                        : 8
# SizeMB                    : 3236
# DataSpaceUsage            : 827136
# IndexSpaceUsage           : 120184
# CreateDate                : 2/19/2020 5:16:25 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:07 PM
# LastDiffBackup            : 8/17/2020 9:30:41 AM
# LastLogBackup             : 8/17/2020 10:30:05 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : Latin1_General_100_CI_AS
# DefaultFileGroup          : USERDATA
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : WWI_DC
# ID                        : 9
# SizeMB                    : 4714.125
# DataSpaceUsage            : 253544
# IndexSpaceUsage           : 116656
# CreateDate                : 6/9/2020 1:30:06 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Transaction
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Simple
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:16 PM
# LastDiffBackup            : 8/17/2020 9:30:43 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : Latin1_General_100_CI_AS
# DefaultFileGroup          : USERDATA
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : True
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : WWI
# ID                        : 10
# SizeMB                    : 3172
# DataSpaceUsage            : 435080
# IndexSpaceUsage           : 98848
# CreateDate                : 2/20/2020 10:44:27 AM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:11 PM
# LastDiffBackup            : 8/17/2020 9:30:42 AM
# LastLogBackup             : 8/17/2020 10:30:05 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : Latin1_General_100_CI_AS
# DefaultFileGroup          : USERDATA
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : DBAdmin
# ID                        : 11
# SizeMB                    : 144
# DataSpaceUsage            : 12312
# IndexSpaceUsage           : 1280
# CreateDate                : 6/12/2020 1:10:42 PM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:12 PM
# LastDiffBackup            : 8/17/2020 9:30:35 AM
# LastLogBackup             : 8/17/2020 10:30:02 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : WWI_DC2
# ID                        : 12
# SizeMB                    : 1336.046875
# DataSpaceUsage            : 1816
# IndexSpaceUsage           : 1584
# CreateDate                : 6/16/2020 4:44:16 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:17 PM
# LastDiffBackup            : 8/17/2020 9:30:44 AM
# LastLogBackup             : 8/17/2020 10:30:06 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : Latin1_General_100_CI_AS
# DefaultFileGroup          : USERDATA
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : True
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : relog
# ID                        : 13
# SizeMB                    : 1104
# DataSpaceUsage            : 670632
# IndexSpaceUsage           : 6832
# CreateDate                : 6/26/2020 3:37:07 PM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:18 PM
# LastDiffBackup            : 8/17/2020 9:30:37 AM
# LastLogBackup             : 8/17/2020 10:30:04 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : PerfmonData
# ID                        : 14
# SizeMB                    : 400
# DataSpaceUsage            : 180144
# IndexSpaceUsage           : 1256
# CreateDate                : 7/22/2020 2:12:55 PM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:16 PM
# LastDiffBackup            : 8/17/2020 9:30:36 AM
# LastLogBackup             : 8/17/2020 10:30:03 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : UatDatabase
# ID                        : 15
# SizeMB                    : 16
# DataSpaceUsage            : 1120
# IndexSpaceUsage           : 1240
# CreateDate                : 2/20/2020 1:57:54 PM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:02 PM
# LastDiffBackup            : 8/17/2020 9:30:41 AM
# LastLogBackup             : 8/17/2020 10:30:05 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : PurgeTest
# ID                        : 16
# SizeMB                    : 272
# DataSpaceUsage            : 9352
# IndexSpaceUsage           : 1384
# CreateDate                : 7/28/2020 2:58:12 PM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:16 PM
# LastDiffBackup            : 8/17/2020 9:30:36 AM
# LastLogBackup             : 8/17/2020 10:30:04 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : BackupTest_Copy
# ID                        : 17
# SizeMB                    : 256
# DataSpaceUsage            : 1208
# IndexSpaceUsage           : 1176
# CreateDate                : 2/20/2020 2:57:51 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:42:49 PM
# LastDiffBackup            : 8/17/2020 9:30:34 AM
# LastLogBackup             : 8/17/2020 10:30:02 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : AuditDatabase
# ID                        : 18
# SizeMB                    : 16
# DataSpaceUsage            : 1152
# IndexSpaceUsage           : 1248
# CreateDate                : 2/20/2020 3:07:27 PM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:42:49 PM
# LastDiffBackup            : 8/17/2020 9:30:34 AM
# LastLogBackup             : 8/17/2020 10:30:01 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : AssessmentInventory
# ID                        : 19
# SizeMB                    : 16
# DataSpaceUsage            : 1232
# IndexSpaceUsage           : 1192
# CreateDate                : 2/25/2020 12:01:59 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:42:48 PM
# LastDiffBackup            : 8/17/2020 9:30:33 AM
# LastLogBackup             : 8/17/2020 10:30:01 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : BackupTest
# ID                        : 20
# SizeMB                    : 256
# DataSpaceUsage            : 1208
# IndexSpaceUsage           : 1176
# CreateDate                : 2/25/2020 12:02:01 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:42:49 PM
# LastDiffBackup            : 8/17/2020 9:30:34 AM
# LastLogBackup             : 8/17/2020 10:30:01 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : DataMasking
# ID                        : 21
# SizeMB                    : 256
# DataSpaceUsage            : 1392
# IndexSpaceUsage           : 1200
# CreateDate                : 2/25/2020 12:02:04 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:42:50 PM
# LastDiffBackup            : 8/17/2020 9:30:35 AM
# LastLogBackup             : 8/17/2020 10:30:02 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : DB1024LOG
# ID                        : 22
# SizeMB                    : 2368
# DataSpaceUsage            : 1201216
# IndexSpaceUsage           : 5648
# CreateDate                : 2/25/2020 12:02:20 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:02 PM
# LastDiffBackup            : 8/17/2020 9:30:35 AM
# LastLogBackup             : 8/17/2020 10:30:02 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : DB256LOG
# ID                        : 23
# SizeMB                    : 2112
# DataSpaceUsage            : 1201216
# IndexSpaceUsage           : 5648
# CreateDate                : 2/25/2020 12:02:35 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:11 PM
# LastDiffBackup            : 8/17/2020 9:30:35 AM
# LastLogBackup             : 8/17/2020 10:30:02 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : dbChangeTrackingMetadata
# ID                        : 24
# SizeMB                    : 16
# DataSpaceUsage            : 1200
# IndexSpaceUsage           : 1184
# CreateDate                : 2/25/2020 12:02:37 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:12 PM
# LastDiffBackup            : 8/17/2020 9:30:35 AM
# LastLogBackup             : 8/17/2020 10:30:02 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : difffileloc
# ID                        : 25
# SizeMB                    : 256
# DataSpaceUsage            : 1208
# IndexSpaceUsage           : 1176
# CreateDate                : 2/25/2020 12:02:41 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:12 PM
# LastDiffBackup            : 8/17/2020 9:30:35 AM
# LastLogBackup             : 8/17/2020 10:30:02 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : DMAReporting
# ID                        : 26
# SizeMB                    : 16
# DataSpaceUsage            : 1280
# IndexSpaceUsage           : 1240
# CreateDate                : 2/25/2020 12:02:43 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:12 PM
# LastDiffBackup            : 8/17/2020 9:30:36 AM
# LastLogBackup             : 8/17/2020 10:30:03 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : DMAReportingTest
# ID                        : 27
# SizeMB                    : 16
# DataSpaceUsage            : 1280
# IndexSpaceUsage           : 1240
# CreateDate                : 2/25/2020 12:02:44 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:12 PM
# LastDiffBackup            : 8/17/2020 9:30:36 AM
# LastLogBackup             : 8/17/2020 10:30:03 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : DMAWarehouse
# ID                        : 28
# SizeMB                    : 336
# DataSpaceUsage            : 62160
# IndexSpaceUsage           : 17328
# CreateDate                : 2/25/2020 12:02:53 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:13 PM
# LastDiffBackup            : 8/17/2020 9:30:36 AM
# LastLogBackup             : 8/17/2020 10:30:03 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : DMAWarehouseTest
# ID                        : 29
# SizeMB                    : 336
# DataSpaceUsage            : 1296
# IndexSpaceUsage           : 1224
# CreateDate                : 2/25/2020 12:02:58 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:13 PM
# LastDiffBackup            : 8/17/2020 9:30:36 AM
# LastLogBackup             : 8/17/2020 10:30:03 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : HealthCheckResults
# ID                        : 30
# SizeMB                    : 344
# DataSpaceUsage            : 28424
# IndexSpaceUsage           : 1464
# CreateDate                : 2/25/2020 12:03:03 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:13 PM
# LastDiffBackup            : 8/17/2020 9:30:36 AM
# LastLogBackup             : 8/17/2020 10:30:03 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : DEFAULT
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : Lahman
# ID                        : 31
# SizeMB                    : 320
# DataSpaceUsage            : 56544
# IndexSpaceUsage           : 44296
# CreateDate                : 2/25/2020 12:03:07 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:13 PM
# LastDiffBackup            : 8/17/2020 9:30:36 AM
# LastLogBackup             : 8/17/2020 10:30:03 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : MAP_SampleDB
# ID                        : 32
# SizeMB                    : 394.4375
# DataSpaceUsage            : 228144
# IndexSpaceUsage           : 84272
# CreateDate                : 2/25/2020 12:03:11 PM
# Compatibility             : Version100
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:15 PM
# LastDiffBackup            : 8/17/2020 9:30:36 AM
# LastLogBackup             : 8/17/2020 10:30:03 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : ProdDb
# ID                        : 33
# SizeMB                    : 256
# DataSpaceUsage            : 7472
# IndexSpaceUsage           : 1216
# CreateDate                : 2/25/2020 12:03:15 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:16 PM
# LastDiffBackup            : 8/17/2020 9:30:36 AM
# LastLogBackup             : 8/17/2020 10:30:03 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : DMAInventory
# ID                        : 34
# SizeMB                    : 16
# DataSpaceUsage            : 1128
# IndexSpaceUsage           : 1240
# CreateDate                : 2/26/2020 11:15:38 AM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:43:12 PM
# LastDiffBackup            : 8/17/2020 9:30:36 AM
# LastLogBackup             : 8/17/2020 10:30:02 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : TestDatabaseProject
# ID                        : 35
# SizeMB                    : 2072
# DataSpaceUsage            : 4808
# IndexSpaceUsage           : 2144
# CreateDate                : 2/25/2020 12:06:08 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:00 PM
# LastDiffBackup            : 8/17/2020 9:30:39 AM
# LastLogBackup             : 8/17/2020 10:30:04 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : Latin1_General_100_CI_AS
# DefaultFileGroup          : USERDATA
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : True
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : TestReporting
# ID                        : 36
# SizeMB                    : 16
# DataSpaceUsage            : 1848
# IndexSpaceUsage           : 1272
# CreateDate                : 2/26/2020 11:45:48 AM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:02 PM
# LastDiffBackup            : 8/17/2020 9:30:41 AM
# LastLogBackup             : 8/17/2020 10:30:05 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : TestWarehouse
# ID                        : 37
# SizeMB                    : 16
# DataSpaceUsage            : 1920
# IndexSpaceUsage           : 1360
# CreateDate                : 2/26/2020 11:45:50 AM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:02 PM
# LastDiffBackup            : 8/17/2020 9:30:41 AM
# LastLogBackup             : 8/17/2020 10:30:05 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : backuptesting
# ID                        : 38
# SizeMB                    : 80
# DataSpaceUsage            : 3464
# IndexSpaceUsage           : 1240
# CreateDate                : 2/26/2020 3:35:00 PM
# Compatibility             : Version140
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:42:50 PM
# LastDiffBackup            : 8/17/2020 9:30:34 AM
# LastLogBackup             : 8/17/2020 10:30:02 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : testdb1
# ID                        : 39
# SizeMB                    : 16
# DataSpaceUsage            : 1192
# IndexSpaceUsage           : 1176
# CreateDate                : 2/25/2020 12:12:17 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:01 PM
# LastDiffBackup            : 8/17/2020 9:30:40 AM
# LastLogBackup             : 8/17/2020 10:30:04 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : testdb2
# ID                        : 40
# SizeMB                    : 16
# DataSpaceUsage            : 1192
# IndexSpaceUsage           : 1176
# CreateDate                : 2/25/2020 12:12:19 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:01 PM
# LastDiffBackup            : 8/17/2020 9:30:40 AM
# LastLogBackup             : 8/17/2020 10:30:04 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : testdb3
# ID                        : 41
# SizeMB                    : 16
# DataSpaceUsage            : 1192
# IndexSpaceUsage           : 1176
# CreateDate                : 2/25/2020 12:12:20 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:01 PM
# LastDiffBackup            : 8/17/2020 9:30:40 AM
# LastLogBackup             : 8/17/2020 10:30:04 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : testdb4
# ID                        : 42
# SizeMB                    : 16
# DataSpaceUsage            : 1192
# IndexSpaceUsage           : 1176
# CreateDate                : 2/25/2020 12:12:22 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:01 PM
# LastDiffBackup            : 8/17/2020 9:30:40 AM
# LastLogBackup             : 8/17/2020 10:30:04 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : testdb5
# ID                        : 43
# SizeMB                    : 16
# DataSpaceUsage            : 1192
# IndexSpaceUsage           : 1176
# CreateDate                : 2/25/2020 12:12:23 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:01 PM
# LastDiffBackup            : 8/17/2020 9:30:40 AM
# LastLogBackup             : 8/17/2020 10:30:04 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : testdb6
# ID                        : 44
# SizeMB                    : 16
# DataSpaceUsage            : 1192
# IndexSpaceUsage           : 1176
# CreateDate                : 2/25/2020 12:12:24 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:02 PM
# LastDiffBackup            : 8/17/2020 9:30:40 AM
# LastLogBackup             : 8/17/2020 10:30:04 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : testdb7
# ID                        : 45
# SizeMB                    : 16
# DataSpaceUsage            : 1192
# IndexSpaceUsage           : 1176
# CreateDate                : 2/25/2020 12:12:25 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:02 PM
# LastDiffBackup            : 8/17/2020 9:30:40 AM
# LastLogBackup             : 8/17/2020 10:30:04 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : testdb8
# ID                        : 46
# SizeMB                    : 16
# DataSpaceUsage            : 1192
# IndexSpaceUsage           : 1176
# CreateDate                : 2/25/2020 12:12:27 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:02 PM
# LastDiffBackup            : 8/17/2020 9:30:40 AM
# LastLogBackup             : 8/17/2020 10:30:05 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : testdb9
# ID                        : 47
# SizeMB                    : 16
# DataSpaceUsage            : 1200
# IndexSpaceUsage           : 1176
# CreateDate                : 2/25/2020 12:12:28 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:02 PM
# LastDiffBackup            : 8/17/2020 9:30:40 AM
# LastLogBackup             : 8/17/2020 10:30:05 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : TestDBA
# ID                        : 48
# SizeMB                    : 10
# DataSpaceUsage            : 1432
# IndexSpaceUsage           : 1184
# CreateDate                : 2/25/2020 12:12:29 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:02 PM
# LastDiffBackup            : 8/17/2020 9:30:41 AM
# LastLogBackup             : 8/17/2020 10:30:05 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : TranAnatomy
# ID                        : 49
# SizeMB                    : 256
# DataSpaceUsage            : 1520
# IndexSpaceUsage           : 1232
# CreateDate                : 2/25/2020 12:12:33 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:02 PM
# LastDiffBackup            : 8/17/2020 9:30:41 AM
# LastLogBackup             : 8/17/2020 10:30:05 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : UatDb
# ID                        : 50
# SizeMB                    : 320
# DataSpaceUsage            : 171224
# IndexSpaceUsage           : 1440
# CreateDate                : 2/25/2020 12:12:38 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:03 PM
# LastDiffBackup            : 8/17/2020 9:30:41 AM
# LastLogBackup             : 8/17/2020 10:30:05 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : WorldWideImporters
# ID                        : 51
# SizeMB                    : 1880
# DataSpaceUsage            : 1848
# IndexSpaceUsage           : 1592
# CreateDate                : 2/25/2020 12:12:53 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:09 PM
# LastDiffBackup            : 8/17/2020 9:30:42 AM
# LastLogBackup             : 8/17/2020 10:30:05 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : Latin1_General_100_CI_AS
# DefaultFileGroup          : USERDATA
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : True
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : BackupTest_copy_03052020
# ID                        : 52
# SizeMB                    : 256
# DataSpaceUsage            : 1208
# IndexSpaceUsage           : 1176
# CreateDate                : 3/5/2020 10:31:21 AM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:42:49 PM
# LastDiffBackup            : 8/17/2020 9:30:34 AM
# LastLogBackup             : 8/17/2020 10:30:02 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : BackupTest_copy_03052020_113500
# ID                        : 53
# SizeMB                    : 256
# DataSpaceUsage            : 1208
# IndexSpaceUsage           : 1176
# CreateDate                : 3/5/2020 11:35:22 AM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:42:49 PM
# LastDiffBackup            : 8/17/2020 9:30:34 AM
# LastLogBackup             : 8/17/2020 10:30:02 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# ...
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:03 PM
# LastDiffBackup            : 8/17/2020 9:30:41 AM
# LastLogBackup             : 8/17/2020 10:30:05 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2017
# Name                      : testdb_copy_03052020_113900
# ID                        : 56
# SizeMB                    : 256
# DataSpaceUsage            : 7720
# IndexSpaceUsage           : 1184
# CreateDate                : 3/9/2020 4:27:40 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 8/14/2020 2:44:01 PM
# LastDiffBackup            : 8/17/2020 9:30:40 AM
# LastLogBackup             : 8/17/2020 10:30:04 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : master
# ID                        : 1
# SizeMB                    : 1954.625
# DataSpaceUsage            : 866280
# IndexSpaceUsage           : 20760
# CreateDate                : 4/8/2003 9:13:36 AM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Simple
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 10/18/2019 11:40:22 AM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : tempdb
# ID                        : 2
# SizeMB                    : 8200
# DataSpaceUsage            : 1160
# IndexSpaceUsage           : 1272
# CreateDate                : 7/30/2020 11:24:55 AM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Simple
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 1/1/0001 12:00:00 AM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : model
# ID                        : 3
# SizeMB                    : 256
# DataSpaceUsage            : 1032
# IndexSpaceUsage           : 1168
# CreateDate                : 4/8/2003 9:13:36 AM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 10/18/2019 11:40:22 AM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : msdb
# ID                        : 4
# SizeMB                    : 1067.5625
# DataSpaceUsage            : 19880
# IndexSpaceUsage           : 4272
# CreateDate                : 4/30/2016 12:46:38 AM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Simple
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 10/18/2019 11:40:22 AM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : AssessmentInventory
# ID                        : 7
# SizeMB                    : 16
# DataSpaceUsage            : 1064
# IndexSpaceUsage           : 1184
# CreateDate                : 2/25/2020 12:13:42 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 5/28/2020 1:45:17 PM
# LastDiffBackup            : 1/7/2020 2:37:19 PM
# LastLogBackup             : 5/28/2020 11:14:45 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : SmalLog
# ID                        : 9
# SizeMB                    : 15617
# DataSpaceUsage            : 14810872
# IndexSpaceUsage           : 1208
# CreateDate                : 2/25/2020 12:15:14 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 5/28/2020 2:08:44 PM
# LastDiffBackup            : 1/7/2020 2:37:20 PM
# LastLogBackup             : 5/28/2020 11:17:50 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : Baselines
# ID                        : 10
# SizeMB                    : 256
# DataSpaceUsage            : 1872
# IndexSpaceUsage           : 1392
# CreateDate                : 2/26/2020 10:29:08 AM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 5/28/2020 1:45:45 PM
# LastDiffBackup            : 1/7/2020 2:37:19 PM
# LastLogBackup             : 5/28/2020 11:16:59 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : ProdDb
# ID                        : 11
# SizeMB                    : 256
# DataSpaceUsage            : 7560
# IndexSpaceUsage           : 1176
# CreateDate                : 3/4/2020 12:39:51 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 5/28/2020 1:46:26 PM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : PvNoneDb
# ID                        : 12
# SizeMB                    : 153
# DataSpaceUsage            : 1632
# IndexSpaceUsage           : 1200
# CreateDate                : 4/6/2020 2:35:39 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : None
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 5/28/2020 1:46:44 PM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : PvTornPageDb
# ID                        : 13
# SizeMB                    : 153
# DataSpaceUsage            : 1632
# IndexSpaceUsage           : 1200
# CreateDate                : 4/6/2020 2:35:40 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : TornPageDetection
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 5/28/2020 1:46:53 PM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : PvCheckSumDb
# ID                        : 14
# SizeMB                    : 153
# DataSpaceUsage            : 1632
# IndexSpaceUsage           : 1200
# CreateDate                : 4/6/2020 2:35:41 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 1/1/0001 12:00:00 AM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : PerfmonTest
# ID                        : 15
# SizeMB                    : 256
# DataSpaceUsage            : 1056
# IndexSpaceUsage           : 1176
# CreateDate                : 4/8/2020 5:10:53 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 5/28/2020 1:46:15 PM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : DefaultConstraint
# ID                        : 17
# SizeMB                    : 256
# DataSpaceUsage            : 1032
# IndexSpaceUsage           : 1168
# CreateDate                : 4/24/2020 11:53:41 AM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 5/28/2020 1:45:55 PM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : ASPState
# ID                        : 18
# SizeMB                    : 1072
# DataSpaceUsage            : 1216
# IndexSpaceUsage           : 1240
# CreateDate                : 5/7/2020 2:27:56 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 5/28/2020 1:45:11 PM
# LastDiffBackup            : 1/1/0001 12:00:00 AM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : True
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : TestDB
# ID                        : 19
# SizeMB                    : 256
# DataSpaceUsage            : 1032
# IndexSpaceUsage           : 1168
# CreateDate                : 5/21/2020 1:32:54 PM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : CONCURRENCY\fgill
# PageVerify                : Checksum
# RecoveryModel             : Full
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 5/28/2020 2:11:09 PM
# LastDiffBackup            : 1/7/2020 2:37:21 PM
# LastLogBackup             : 5/28/2020 11:18:36 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False
#
# SqlInstance               : DESKTOP-1KGJIH9\DEV2016
# Name                      : distribution
# ID                        : 33
# SizeMB                    : 262
# DataSpaceUsage            : 1728
# IndexSpaceUsage           : 1648
# CreateDate                : 9/23/2019 10:45:14 AM
# Compatibility             : Version130
# LogReuseWaitStatus        : Nothing
# Owner                     : sa
# PageVerify                : Checksum
# RecoveryModel             : Simple
# DatabaseEngineEdition     : Enterprise
# LastFullBackup            : 5/28/2020 1:46:06 PM
# LastDiffBackup            : 1/7/2020 2:37:20 PM
# LastLogBackup             : 1/1/0001 12:00:00 AM
# AutoClose                 : False
# AutoShrink                : False
# Collation                 : SQL_Latin1_General_CP1_CI_AS
# DefaultFileGroup          : PRIMARY
# DefaultSchema             : dbo
# HasMemoryOptimizedObjects : False
# IsReadCommittedSnapshotOn : False

# %% [markdown]
# # Chapter 2

# %% [markdown]
# # Get VLF Info
# This code returns VLF counts for each database on an instance.

# %%
#$instances = Get-Content -Path C:\Users\fgill\Documents\GitHub\AzureDataStudioAndContainers\instances.txt;

foreach($instance in $instances)
{
    $vlfs = Get-DbaDbVirtualLogFile -SqlInstance $instance;
    $vlfs | Group-Object -Property Database | Select-Object -Property Count, Name;
}
# Out:
# Count Name
# ----- ----
#     8 AdventureWorks2014
#     4 AssessmentInventory
#     4 AuditDatabase
#     4 auditdb
#     8 BackupTest
#     8 BackupTest_Copy
#     8 BackupTest_copy_03052020
#     8 BackupTest_copy_03052020_113500
#     8 backuptesting
#     8 Baselines
#     8 DataMasking
#    16 DB1024LOG
#    32 DB256LOG
#     8 DBAdmin
#     4 dbChangeTrackingMetadata
#     8 difffileloc
#     4 DMAInventory
#     4 DMAReporting
#     4 DMAReportingTest
#     8 DMAWarehouse
#     8 DMAWarehouseTest
#    20 HealthCheckResults
#    12 Lahman
#   123 MAP_SampleDB
#    16 PerfmonData
#     8 ProdDb
#    16 PurgeTest
#    28 relog
#    14 SmalLog_copy_03052020_113900
#    20 TestDatabaseProject
#     8 testdb_copy_03052020_113900
#     4 testdb1
#     4 testdb2
#     4 testdb3
#     4 testdb4
#     4 testdb5
#     4 testdb6
#     4 testdb7
#     4 testdb8
#     4 testdb9
#     8 TestDBA
#     4 TestReporting
#     4 TestWarehouse
#     8 TranAnatomy
#     4 UatDatabase
#     8 UatDb
#     8 UatDb_copy_03092020_151500
#    12 WideWorldImporters
#     8 WorldWideImporters
#     8 WWI
#    16 WWI_DC
#     8 WWI_DC2
#     4 ASPState
#     4 AssessmentInventory
#     8 Baselines
#     8 DefaultConstraint
#     8 PerfmonTest
#     8 ProdDb
#     4 PvCheckSumDb
#     4 PvNoneDb
#     4 PvTornPageDb
#    14 SmalLog
#     8 TestDB

# %% [markdown]
# # Chapter 3

# %% [markdown]
# # Get VLF Info Grouped By Status Test
# This code return VLF counts for each database on an instance grouped by VLF status.

# %%
#$instances = Get-Content -Path C:\Users\fgill\Documents\GitHub\AzureDataStudioAndContainers\instances.txt;

foreach($instance in $instances)
{
    $vlfs = Get-DbaDbVirtualLogFile -SqlInstance $instance;
    $groups = $vlfs | Group-Object -Property Database, Status | Select-Object -Property Count, Name; 

    foreach($group in $groups)
    {
        
        $name = $group.Name;
        $count = $group.Count;
        $parsed = ConvertFrom-String $name -Delimiter "," -PropertyNames DatabaseName, VlfStatus;
        $vlfstatus = New-Object -TypeName psobject;
        $vlfstatus | Add-Member -MemberType NoteProperty -Name DatabaseName -Value $parsed.DatabaseName;
        $vlfstatus | Add-Member -MemberType NoteProperty -Name VlfStatus -Value $parsed.VlfStatus;
        $vlfstatus | Add-Member -MemberType NoteProperty -Name VlfCount -Value $count;
        $vlfstatus | Select-Object -Property DatabaseName, VlfStatus, VlfCount;
    }
}
# Out:
# DatabaseName                    VlfStatus VlfCount
# ------------                    --------- --------
# AdventureWorks2014                      0        7
# AdventureWorks2014                      2        1
# AssessmentInventory                     0        3
# AssessmentInventory                     2        1
# AuditDatabase                           0        3
# AuditDatabase                           2        1
# auditdb                                 0        3
# auditdb                                 2        1
# BackupTest                              0        7
# BackupTest                              2        1
# BackupTest_Copy                         0        7
# BackupTest_Copy                         2        1
# BackupTest_copy_03052020                0        7
# BackupTest_copy_03052020                2        1
# BackupTest_copy_03052020_113500         0        7
# BackupTest_copy_03052020_113500         2        1
# backuptesting                           0        7
# backuptesting                           2        1
# Baselines                               0        7
# Baselines                               2        1
# DataMasking                             0        7
# DataMasking                             2        1
# DB1024LOG                               0       15
# DB1024LOG                               2        1
# DB256LOG                                0       31
# DB256LOG                                2        1
# DBAdmin                                 0        7
# DBAdmin                                 2        1
# dbChangeTrackingMetadata                0        3
# dbChangeTrackingMetadata                2        1
# difffileloc                             0        7
# difffileloc                             2        1
# DMAInventory                            0        3
# DMAInventory                            2        1
# DMAReporting                            0        3
# DMAReporting                            2        1
# DMAReportingTest                        0        3
# DMAReportingTest                        2        1
# DMAWarehouse                            0        7
# DMAWarehouse                            2        1
# DMAWarehouseTest                        0        7
# DMAWarehouseTest                        2        1
# HealthCheckResults                      0       19
# HealthCheckResults                      2        1
# Lahman                                  0       11
# Lahman                                  2        1
# MAP_SampleDB                            0      122
# MAP_SampleDB                            2        1
# PerfmonData                             0       15
# PerfmonData                             2        1
# ProdDb                                  0        7
# ProdDb                                  2        1
# PurgeTest                               0       15
# PurgeTest                               2        1
# relog                                   0       27
# relog                                   2        1
# SmalLog_copy_03052020_113900            0       13
# SmalLog_copy_03052020_113900            2        1
# TestDatabaseProject                     2       20
# testdb_copy_03052020_113900             0        7
# testdb_copy_03052020_113900             2        1
# testdb1                                 0        3
# testdb1                                 2        1
# testdb2                                 0        3
# testdb2                                 2        1
# testdb3                                 0        3
# testdb3                                 2        1
# testdb4                                 0        3
# testdb4                                 2        1
# testdb5                                 0        3
# testdb5                                 2        1
# testdb6                                 0        3
# testdb6                                 2        1
# testdb7                                 0        3
# testdb7                                 2        1
# testdb8                                 0        3
# testdb8                                 2        1
# testdb9                                 0        3
# testdb9                                 2        1
# TestDBA                                 0        7
# TestDBA                                 2        1
# TestReporting                           0        3
# TestReporting                           2        1
# TestWarehouse                           0        3
# TestWarehouse                           2        1
# TranAnatomy                             0        7
# TranAnatomy                             2        1
# UatDatabase                             0        3
# UatDatabase                             2        1
# UatDb                                   0        7
# UatDb                                   2        1
# UatDb_copy_03092020_151500              0        7
# UatDb_copy_03092020_151500              2        1
# WideWorldImporters                      0       11
# WideWorldImporters                      2        1
# WorldWideImporters                      0        6
# WorldWideImporters                      2        2
# WWI                                     0        7
# WWI                                     2        1
# WWI_DC                                  2       16
# WWI_DC2                                 0        7
# WWI_DC2                                 2        1
# ASPState                                0        3
# ASPState                                2        1
# AssessmentInventory                     0        3
# AssessmentInventory                     2        1
# Baselines                               0        7
# Baselines                               2        1
# DefaultConstraint                       0        7
# DefaultConstraint                       2        1
# PerfmonTest                             0        7
# PerfmonTest                             2        1
# ProdDb                                  0        7
# ProdDb                                  2        1
# PvCheckSumDb                            0        3
# PvCheckSumDb                            2        1
# PvNoneDb                                0        3
# PvNoneDb                                2        1
# PvTornPageDb                            0        3
# PvTornPageDb                            2        1
# SmalLog                                 0       13
# SmalLog                                 2        1
# TestDB                                  0        7
# TestDB                                  2        1

# %% [markdown]
# # Chapter 4

# %% [markdown]
# # Get Data File Information
# This code returns detailed information about data files on an instance of SQL Server.

# %%
#$instances = Get-Content -Path C:\Users\fgill\Documents\GitHub\AzureDataStudioAndContainers\instances.txt;

foreach($instance in $instances)
{
    Get-DbaDbFile -SqlInstance $instance | Select-Object -Property SqlInstance, Database, FileGroupName, TypeDescription, LogicalName, PhysicalName, MaxSize, Growth, GrowthType, Size, UsedSpace, AvailableSpace, NumberOfDiskWrites, NumberOfDiskReads, ReadFromDisk, WritesToDisk | Where TypeDescription -eq "Rows";
}
# Out:
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : master
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : master
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\master.mdf
# MaxSize            : Unlimited
# Growth             : 10
# GrowthType         : Percent
# Size               : 369.62 MB
# UsedSpace          : 352.75 MB
# AvailableSpace     : 16.88 MB
# NumberOfDiskWrites : 3049
# NumberOfDiskReads  : 9511
# ReadFromDisk       : 1.10 GB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : tempdev
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\tempdb.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 16.00 MB
# UsedSpace          : 3.12 MB
# AvailableSpace     : 12.88 MB
# NumberOfDiskWrites : 1406
# NumberOfDiskReads  : 888
# ReadFromDisk       : 38.71 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp2
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\tempdb_mssql_2.ndf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 16.00 MB
# UsedSpace          : 320.00 KB
# AvailableSpace     : 15.69 MB
# NumberOfDiskWrites : 781
# NumberOfDiskReads  : 143
# ReadFromDisk       : 6.92 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp3
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\tempdb_mssql_3.ndf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 16.00 MB
# UsedSpace          : 448.00 KB
# AvailableSpace     : 15.56 MB
# NumberOfDiskWrites : 817
# NumberOfDiskReads  : 243
# ReadFromDisk       : 11.82 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp4
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\tempdb_mssql_4.ndf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 16.00 MB
# UsedSpace          : 320.00 KB
# AvailableSpace     : 15.69 MB
# NumberOfDiskWrites : 775
# NumberOfDiskReads  : 181
# ReadFromDisk       : 9.21 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp5
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\tempdb_mssql_5.ndf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 16.00 MB
# UsedSpace          : 704.00 KB
# AvailableSpace     : 15.31 MB
# NumberOfDiskWrites : 845
# NumberOfDiskReads  : 166
# ReadFromDisk       : 8.07 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp6
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\tempdb_mssql_6.ndf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 16.00 MB
# UsedSpace          : 448.00 KB
# AvailableSpace     : 15.56 MB
# NumberOfDiskWrites : 819
# NumberOfDiskReads  : 178
# ReadFromDisk       : 8.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp7
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\tempdb_mssql_7.ndf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 16.00 MB
# UsedSpace          : 896.00 KB
# AvailableSpace     : 15.12 MB
# NumberOfDiskWrites : 781
# NumberOfDiskReads  : 142
# ReadFromDisk       : 6.98 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp8
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\tempdb_mssql_8.ndf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 16.00 MB
# UsedSpace          : 832.00 KB
# AvailableSpace     : 15.19 MB
# NumberOfDiskWrites : 829
# NumberOfDiskReads  : 153
# ReadFromDisk       : 7.31 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : model
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : modeldev
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\model.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.62 MB
# AvailableSpace     : 5.38 MB
# NumberOfDiskWrites : 53
# NumberOfDiskReads  : 233
# ReadFromDisk       : 21.80 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : msdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : MSDBData
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\MSDBData.mdf
# MaxSize            : Unlimited
# Growth             : 10
# GrowthType         : Percent
# Size               : 611.12 MB
# UsedSpace          : 558.19 MB
# AvailableSpace     : 52.94 MB
# NumberOfDiskWrites : 28715
# NumberOfDiskReads  : 53140
# ReadFromDisk       : 3.44 GB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : AdventureWorks2014
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : AdventureWorks2014_Data
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\AdventureWorks2014_Data.mdf
# MaxSize            : Unlimited
# Growth             : 16384
# GrowthType         : kb
# Size               : 253.25 MB
# UsedSpace          : 203.19 MB
# AvailableSpace     : 50.06 MB
# NumberOfDiskWrites : 74
# NumberOfDiskReads  : 2866
# ReadFromDisk       : 732.95 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : auditdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : auditdb
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\auditdb.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.81 MB
# AvailableSpace     : 5.19 MB
# NumberOfDiskWrites : 1495
# NumberOfDiskReads  : 1072
# ReadFromDisk       : 60.48 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : Baselines
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : Baselines
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\Baselines.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 4.62 MB
# AvailableSpace     : 123.38 MB
# NumberOfDiskWrites : 1495
# NumberOfDiskReads  : 1247
# ReadFromDisk       : 83.16 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WideWorldImporters
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : WWI_Primary
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WideWorldImporters.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 1,024.00 MB
# UsedSpace          : 11.00 MB
# AvailableSpace     : 1,013.00 MB
# NumberOfDiskWrites : 9858
# NumberOfDiskReads  : 4062
# ReadFromDisk       : 241.46 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WideWorldImporters
# FileGroupName      : USERDATA
# TypeDescription    : ROWS
# LogicalName        : WWI_UserData
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WideWorldImporters_UserData.ndf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 2.00 GB
# UsedSpace          : 925.75 MB
# AvailableSpace     : 1.10 GB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 9763
# ReadFromDisk       : 2.92 GB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WWI_DC
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : WWI_Primary
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WWI_DC.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 1,024.00 MB
# UsedSpace          : 12.50 MB
# AvailableSpace     : 1,011.50 MB
# NumberOfDiskWrites : 2642
# NumberOfDiskReads  : 3143
# ReadFromDisk       : 228.18 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WWI_DC
# FileGroupName      : USERDATA
# TypeDescription    : ROWS
# LogicalName        : WWI_UserData
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WWI_DC_UserData.ndf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 2.00 GB
# UsedSpace          : 382.19 MB
# AvailableSpace     : 1.63 GB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 6932
# ReadFromDisk       : 1.23 GB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WWI
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : WWI_Primary
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WWI.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 1,024.00 MB
# UsedSpace          : 10.75 MB
# AvailableSpace     : 1,013.25 MB
# NumberOfDiskWrites : 9819
# NumberOfDiskReads  : 3939
# ReadFromDisk       : 239.55 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WWI
# FileGroupName      : USERDATA
# TypeDescription    : ROWS
# LogicalName        : WWI_UserData
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WWI_UserData.ndf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 2.00 GB
# UsedSpace          : 521.25 MB
# AvailableSpace     : 1.49 GB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 6732
# ReadFromDisk       : 1.65 GB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DBAdmin
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : DBAdmin
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DBAdmin.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 72.00 MB
# UsedSpace          : 14.31 MB
# AvailableSpace     : 57.69 MB
# NumberOfDiskWrites : 1505
# NumberOfDiskReads  : 1031
# ReadFromDisk       : 98.59 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WWI_DC2
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : WorldWideImporters
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WWI_DC2_Primary.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 5.44 MB
# AvailableSpace     : 122.56 MB
# NumberOfDiskWrites : 1502
# NumberOfDiskReads  : 1128
# ReadFromDisk       : 78.92 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WWI_DC2
# FileGroupName      : USERDATA
# TypeDescription    : ROWS
# LogicalName        : USERDATA_AF48E70
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WWI_DC2_USERDATA_AF48E70.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 320.00 KB
# AvailableSpace     : 127.69 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 87
# ReadFromDisk       : 5.69 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : relog
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : relog
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\relog.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 712.00 MB
# UsedSpace          : 665.75 MB
# AvailableSpace     : 46.25 MB
# NumberOfDiskWrites : 1507
# NumberOfDiskReads  : 3992
# ReadFromDisk       : 2.06 GB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : PerfmonData
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : PerfmonData
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\PerfmonData.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 200.00 MB
# UsedSpace          : 177.81 MB
# AvailableSpace     : 22.19 MB
# NumberOfDiskWrites : 1508
# NumberOfDiskReads  : 1720
# ReadFromDisk       : 599.05 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : UatDatabase
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : UatDatabase
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\UatDatabase.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1071
# ReadFromDisk       : 59.84 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : PurgeTest
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : PurgeTest
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\PurgeTest.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 72.00 MB
# UsedSpace          : 11.44 MB
# AvailableSpace     : 60.56 MB
# NumberOfDiskWrites : 1265
# NumberOfDiskReads  : 1265
# ReadFromDisk       : 91.34 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : BackupTest_Copy
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : BackupTest
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\BackupTest_Copy.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 2.94 MB
# AvailableSpace     : 125.06 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1142
# ReadFromDisk       : 70.66 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : AuditDatabase
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : AuditDatabase
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\AuditDatabase.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 3.00 MB
# AvailableSpace     : 5.00 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1091
# ReadFromDisk       : 60.80 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : AssessmentInventory
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : AssessmentInventory
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\AssessmentInventory.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 3.00 MB
# AvailableSpace     : 5.00 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1103
# ReadFromDisk       : 61.09 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : BackupTest
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : BackupTest
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\BackupTest.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 2.94 MB
# AvailableSpace     : 125.06 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1129
# ReadFromDisk       : 70.38 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DataMasking
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : DataMasking
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DataMasking.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 3.12 MB
# AvailableSpace     : 124.88 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1237
# ReadFromDisk       : 77.95 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DB1024LOG
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : DB1024LOG
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DB1024LOG.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 1.19 GB
# UsedSpace          : 1.15 GB
# AvailableSpace     : 36.75 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 7215
# ReadFromDisk       : 3.67 GB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DB256LOG
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : DB256LOG
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DB256LOG.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 1.19 GB
# UsedSpace          : 1.15 GB
# AvailableSpace     : 36.75 MB
# NumberOfDiskWrites : 1497
# NumberOfDiskReads  : 7207
# ReadFromDisk       : 3.67 GB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : dbChangeTrackingMetadata
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : dbChangeTrackingMetadata
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\dbChangeTrackingMetadata.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1077
# ReadFromDisk       : 61.88 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : difffileloc
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : difffileloc
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\difffileloc.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 2.75 MB
# AvailableSpace     : 125.25 MB
# NumberOfDiskWrites : 1497
# NumberOfDiskReads  : 1102
# ReadFromDisk       : 70.19 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DMAReporting
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : DMAReporting
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DMAReporting.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 3.19 MB
# AvailableSpace     : 4.81 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1087
# ReadFromDisk       : 62.86 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DMAReportingTest
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : DMAReportingTest
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DMAReportingTest.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 3.25 MB
# AvailableSpace     : 4.75 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1091
# ReadFromDisk       : 63.46 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DMAWarehouse
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : DMAWarehouse
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DMAWarehouse.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 136.00 MB
# UsedSpace          : 80.75 MB
# AvailableSpace     : 55.25 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1559
# ReadFromDisk       : 313.98 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DMAWarehouseTest
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : DMAWarehouseTest
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DMAWarehouseTest.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 136.00 MB
# UsedSpace          : 3.19 MB
# AvailableSpace     : 132.81 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1122
# ReadFromDisk       : 73.22 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : HealthCheckResults
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : HealthCheckResults
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\HealthCheckResults.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 3.56 MB
# AvailableSpace     : 4.44 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1370
# ReadFromDisk       : 88.55 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : HealthCheckResults
# FileGroupName      : DEFAULT
# TypeDescription    : ROWS
# LogicalName        : HealthCheckResults_1
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\HealthCheckResults_1.ndf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 72.00 MB
# UsedSpace          : 27.44 MB
# AvailableSpace     : 44.56 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 342
# ReadFromDisk       : 89.85 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : Lahman
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : Lahman
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\Lahman.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 112.19 MB
# AvailableSpace     : 15.81 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 2270
# ReadFromDisk       : 441.51 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : MAP_SampleDB
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : MAP_SampleDB
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\MAP_SampleDB.mdf
# MaxSize            : Unlimited
# Growth             : 1024
# GrowthType         : kb
# Size               : 312.00 MB
# UsedSpace          : 312.00 MB
# AvailableSpace     : 0 B
# NumberOfDiskWrites : 1491
# NumberOfDiskReads  : 4093
# ReadFromDisk       : 1.11 GB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : ProdDb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : ProdDb
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\ProdDb.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 9.00 MB
# AvailableSpace     : 119.00 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1095
# ReadFromDisk       : 88.07 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DMAInventory
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : DMAInventory
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DMAInventory.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 1511
# NumberOfDiskReads  : 1049
# ReadFromDisk       : 60.90 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : TestDatabaseProject
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : TestDatabaseProject
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\TestDatabaseProject_Primary.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 9.31 MB
# AvailableSpace     : 118.69 MB
# NumberOfDiskWrites : 9821
# NumberOfDiskReads  : 2981
# ReadFromDisk       : 203.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : TestDatabaseProject
# FileGroupName      : USERDATA
# TypeDescription    : ROWS
# LogicalName        : USERDATA_4A036648
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\TestDatabaseProject_USERDATA_4A036648.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 320.00 KB
# AvailableSpace     : 127.69 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 106
# ReadFromDisk       : 7.35 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : TestReporting
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : TestReporting
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\TestReporting.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 3.69 MB
# AvailableSpace     : 4.31 MB
# NumberOfDiskWrites : 1513
# NumberOfDiskReads  : 1105
# ReadFromDisk       : 63.84 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : TestWarehouse
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : TestWarehouse
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\TestWarehouse.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 4.44 MB
# AvailableSpace     : 3.56 MB
# NumberOfDiskWrites : 1513
# NumberOfDiskReads  : 1168
# ReadFromDisk       : 67.40 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : backuptesting
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : backuptesting
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\backuptesting.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 5.19 MB
# AvailableSpace     : 2.81 MB
# NumberOfDiskWrites : 1506
# NumberOfDiskReads  : 1218
# ReadFromDisk       : 71.10 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb1
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : testdb1
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb1.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1085
# ReadFromDisk       : 61.81 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb2
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : testdb2
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb2.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1070
# ReadFromDisk       : 61.49 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb3
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : testdb3
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb3.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1067
# ReadFromDisk       : 61.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb4
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : testdb4
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb4.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1064
# ReadFromDisk       : 61.25 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb5
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : testdb5
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb5.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1069
# ReadFromDisk       : 61.51 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb6
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : testdb6
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb6.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1064
# ReadFromDisk       : 61.28 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb7
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : testdb7
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb7.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1075
# ReadFromDisk       : 61.80 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb8
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : testdb8
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb8.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1082
# ReadFromDisk       : 61.92 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb9
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : testdb9
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb9.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1071
# ReadFromDisk       : 61.55 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : TestDBA
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : TestDBA
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\TestDBA.mdf
# MaxSize            : Unlimited
# Growth             : 1024
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 3.19 MB
# AvailableSpace     : 4.81 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1081
# ReadFromDisk       : 62.26 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : TranAnatomy
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : TranAnatomy
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\TranAnatomy.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 3.31 MB
# AvailableSpace     : 124.69 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1064
# ReadFromDisk       : 71.17 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : UatDb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : UatDb
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\UatDb.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 192.00 MB
# UsedSpace          : 173.19 MB
# AvailableSpace     : 18.81 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1754
# ReadFromDisk       : 590.06 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WorldWideImporters
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : WorldWideImporters
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WorldWideImporters_Primary.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 5.44 MB
# AvailableSpace     : 122.56 MB
# NumberOfDiskWrites : 1497
# NumberOfDiskReads  : 1114
# ReadFromDisk       : 78.97 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WorldWideImporters
# FileGroupName      : USERDATA
# TypeDescription    : ROWS
# LogicalName        : USERDATA_AF48E70
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WorldWideImporters_USERDATA_AF48E70.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 320.00 KB
# AvailableSpace     : 127.69 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 87
# ReadFromDisk       : 5.69 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : BackupTest_copy_03052020
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : BackupTest
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\BackupTest_copy_03052020.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 2.94 MB
# AvailableSpace     : 125.06 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1084
# ReadFromDisk       : 70.90 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : BackupTest_copy_03052020_113500
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : BackupTest
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\BackupTest_copy_03052020_113500.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 2.94 MB
# AvailableSpace     : 125.06 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1082
# ReadFromDisk       : 71.09 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : SmalLog_copy_03052020_113900
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : SmalLog
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\SmalLog_copy_03052020_113900.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 14.19 GB
# UsedSpace          : 14.13 GB
# AvailableSpace     : 60.50 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 56166
# ReadFromDisk       : 43.13 GB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : UatDb_copy_03092020_151500
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : ProdDb
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\UatDb_copy_03092020_151500.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 9.19 MB
# AvailableSpace     : 118.81 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1055
# ReadFromDisk       : 87.53 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb_copy_03052020_113900
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : ProdDb
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb_copy_03052020_113900.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 9.19 MB
# AvailableSpace     : 118.81 MB
# NumberOfDiskWrites : 1496
# NumberOfDiskReads  : 1619
# ReadFromDisk       : 116.80 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : master
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : master
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\master.mdf
# MaxSize            : Unlimited
# Growth             : 1048576
# GrowthType         : kb
# Size               : 871.81 MB
# UsedSpace          : 868.25 MB
# AvailableSpace     : 3.56 MB
# NumberOfDiskWrites : 401
# NumberOfDiskReads  : 1799
# ReadFromDisk       : 93.86 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : tempdev
# PhysicalName       : C:\temp\tempdb\tempdev.mdf
# MaxSize            : Unlimited
# Growth             : 1048576
# GrowthType         : kb
# Size               : 1,024.00 MB
# UsedSpace          : 2.69 MB
# AvailableSpace     : 1,021.31 MB
# NumberOfDiskWrites : 2940
# NumberOfDiskReads  : 666
# ReadFromDisk       : 30.66 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp2
# PhysicalName       : C:\temp\tempdb\temp2.mdf
# MaxSize            : Unlimited
# Growth             : 1048576
# GrowthType         : kb
# Size               : 1,024.00 MB
# UsedSpace          : 576.00 KB
# AvailableSpace     : 1,023.44 MB
# NumberOfDiskWrites : 2103
# NumberOfDiskReads  : 42
# ReadFromDisk       : 2.23 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp3
# PhysicalName       : C:\temp\tempdb\temp3.mdf
# MaxSize            : Unlimited
# Growth             : 1048576
# GrowthType         : kb
# Size               : 1,024.00 MB
# UsedSpace          : 1.88 MB
# AvailableSpace     : 1,022.12 MB
# NumberOfDiskWrites : 2017
# NumberOfDiskReads  : 47
# ReadFromDisk       : 2.37 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp4
# PhysicalName       : C:\temp\tempdb\temp4.mdf
# MaxSize            : Unlimited
# Growth             : 1048576
# GrowthType         : kb
# Size               : 1,024.00 MB
# UsedSpace          : 128.00 KB
# AvailableSpace     : 1,023.88 MB
# NumberOfDiskWrites : 2194
# NumberOfDiskReads  : 44
# ReadFromDisk       : 2.34 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp5
# PhysicalName       : C:\temp\tempdb\temp5.mdf
# MaxSize            : Unlimited
# Growth             : 1048576
# GrowthType         : kb
# Size               : 1,024.00 MB
# UsedSpace          : 512.00 KB
# AvailableSpace     : 1,023.50 MB
# NumberOfDiskWrites : 1941
# NumberOfDiskReads  : 46
# ReadFromDisk       : 2.28 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp6
# PhysicalName       : C:\temp\tempdb\temp6.mdf
# MaxSize            : Unlimited
# Growth             : 1048576
# GrowthType         : kb
# Size               : 1,024.00 MB
# UsedSpace          : 320.00 KB
# AvailableSpace     : 1,023.69 MB
# NumberOfDiskWrites : 2116
# NumberOfDiskReads  : 37
# ReadFromDisk       : 1.91 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp7
# PhysicalName       : C:\temp\tempdb\temp7.mdf
# MaxSize            : Unlimited
# Growth             : 1048576
# GrowthType         : kb
# Size               : 1,024.00 MB
# UsedSpace          : 320.00 KB
# AvailableSpace     : 1,023.69 MB
# NumberOfDiskWrites : 2062
# NumberOfDiskReads  : 42
# ReadFromDisk       : 2.23 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : tempdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : temp8
# PhysicalName       : C:\temp\tempdb\temp8.mdf
# MaxSize            : Unlimited
# Growth             : 1048576
# GrowthType         : kb
# Size               : 1,024.00 MB
# UsedSpace          : 960.00 KB
# AvailableSpace     : 1,023.06 MB
# NumberOfDiskWrites : 1991
# NumberOfDiskReads  : 43
# ReadFromDisk       : 2.20 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : model
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : modeldev
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\model.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 2.56 MB
# AvailableSpace     : 125.44 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 339
# ReadFromDisk       : 135.28 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : msdb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : MSDBData
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\MSDBData.mdf
# MaxSize            : Unlimited
# Growth             : 1048576
# GrowthType         : kb
# Size               : 1.02 GB
# UsedSpace          : 25.62 MB
# AvailableSpace     : 1,022.31 MB
# NumberOfDiskWrites : 8123
# NumberOfDiskReads  : 4854
# ReadFromDisk       : 248.58 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : AssessmentInventory
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : AssessmentInventory
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\AssessmentInventory.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.88 MB
# AvailableSpace     : 5.12 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 745
# ReadFromDisk       : 39.00 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : SmalLog
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : SmalLog
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\SmalLog.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 14.19 GB
# UsedSpace          : 14.13 GB
# AvailableSpace     : 60.62 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 960
# ReadFromDisk       : 52.57 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : Baselines
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : Baselines
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\Baselines.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 4.38 MB
# AvailableSpace     : 123.62 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 721
# ReadFromDisk       : 38.64 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : ProdDb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : ProdDb
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\ProdDb.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 9.06 MB
# AvailableSpace     : 118.94 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 699
# ReadFromDisk       : 38.16 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : PvNoneDb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : PvNoneDb
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\PvNoneDb.mdf
# MaxSize            : Unlimited
# Growth             : 102400
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 3.38 MB
# AvailableSpace     : 124.62 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 691
# ReadFromDisk       : 37.74 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : PvTornPageDb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : PvTornPageDb
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\PvTornPageDb.mdf
# MaxSize            : Unlimited
# Growth             : 102400
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 3.38 MB
# AvailableSpace     : 124.62 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 678
# ReadFromDisk       : 36.72 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : PvCheckSumDb
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : PvCheckSumDb
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\PvCheckSumDb.mdf
# MaxSize            : Unlimited
# Growth             : 102400
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 3.38 MB
# AvailableSpace     : 124.62 MB
# NumberOfDiskWrites : 2
# NumberOfDiskReads  : 657
# ReadFromDisk       : 35.87 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : PerfmonTest
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : PerfmonTest
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\PerfmonTest.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 2.75 MB
# AvailableSpace     : 125.25 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 660
# ReadFromDisk       : 35.87 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : DefaultConstraint
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : DefaultConstraint
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\DefaultConstraint.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 2.56 MB
# AvailableSpace     : 125.44 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 663
# ReadFromDisk       : 36.09 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : ASPState
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : ASPState
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\ASPState.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 3.06 MB
# AvailableSpace     : 124.94 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 567
# ReadFromDisk       : 30.96 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : TestDB
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : TestDB
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\TestDB.mdf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 2.56 MB
# AvailableSpace     : 125.44 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 657
# ReadFromDisk       : 35.91 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : distribution
# FileGroupName      : PRIMARY
# TypeDescription    : ROWS
# LogicalName        : distribution
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\Data\distribution.MDF
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 133.00 MB
# UsedSpace          : 5.56 MB
# AvailableSpace     : 127.44 MB
# NumberOfDiskWrites : 3
# NumberOfDiskReads  : 847
# ReadFromDisk       : 47.23 MB
# WritesToDisk       :

# %% [markdown]
# # Chapter 5

# %% [markdown]
# # Get Log File Information
# This code returns detailed information about transaction log files on an instance of SQL Server.

# %%
#$instances = Get-Content -Path C:\Users\fgill\Documents\GitHub\AzureDataStudioAndContainers\instances.txt;

foreach($instance in $instances)
{
    Get-DbaDbFile -SqlInstance $instance | Select-Object -Property SqlInstance, Database, FileGroupName, TypeDescription, LogicalName, PhysicalName, MaxSize, Growth, GrowthType, Size, UsedSpace, AvailableSpace, NumberOfDiskWrites, NumberOfDiskReads, ReadFromDisk, WritesToDisk | Where TypeDescription -eq "Log";
}
# Out:
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : master
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : mastlog
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\mastlog.ldf
# MaxSize            : Unlimited
# Growth             : 10
# GrowthType         : Percent
# Size               : 8.19 MB
# UsedSpace          : 1.72 MB
# AvailableSpace     : 6.47 MB
# NumberOfDiskWrites : 258669
# NumberOfDiskReads  : 50
# ReadFromDisk       : 3.15 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : tempdb
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : templog
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\templog.ldf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 72.00 MB
# UsedSpace          : 6.26 MB
# AvailableSpace     : 65.74 MB
# NumberOfDiskWrites : 15937
# NumberOfDiskReads  : 36
# ReadFromDisk       : 1.17 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : model
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : modellog
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\modellog.ldf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.11 MB
# AvailableSpace     : 5.89 MB
# NumberOfDiskWrites : 67
# NumberOfDiskReads  : 19
# ReadFromDisk       : 1,004.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : msdb
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : MSDBLog
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\MSDBLog.ldf
# MaxSize            : 2.00 TB
# Growth             : 10
# GrowthType         : Percent
# Size               : 894.88 MB
# UsedSpace          : 887.97 MB
# AvailableSpace     : 6.91 MB
# NumberOfDiskWrites : 45734
# NumberOfDiskReads  : 163
# ReadFromDisk       : 38.98 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : AdventureWorks2014
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : AdventureWorks2014_Log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\AdventureWorks2014_Log.ldf
# MaxSize            : 2.00 TB
# Growth             : 16384
# GrowthType         : kb
# Size               : 18.00 MB
# UsedSpace          : 4.14 MB
# AvailableSpace     : 13.86 MB
# NumberOfDiskWrites : 858
# NumberOfDiskReads  : 35
# ReadFromDisk       : 1.10 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : auditdb
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : auditdb_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\auditdb_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 1.30 MB
# AvailableSpace     : 6.70 MB
# NumberOfDiskWrites : 4406
# NumberOfDiskReads  : 788
# ReadFromDisk       : 3.26 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : Baselines
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : Baselines_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\Baselines_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 14.08 MB
# AvailableSpace     : 113.92 MB
# NumberOfDiskWrites : 4407
# NumberOfDiskReads  : 791
# ReadFromDisk       : 3.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WideWorldImporters
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : WWI_Log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WideWorldImporters.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 164.00 MB
# UsedSpace          : 16.39 MB
# AvailableSpace     : 147.61 MB
# NumberOfDiskWrites : 17484
# NumberOfDiskReads  : 832
# ReadFromDisk       : 82.59 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WWI_DC
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : WWI_Log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WWI_DC.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 228.00 MB
# UsedSpace          : 219.30 MB
# AvailableSpace     : 8.70 MB
# NumberOfDiskWrites : 22636
# NumberOfDiskReads  : 3274
# ReadFromDisk       : 2.85 GB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WWI
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : WWI_Log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WWI.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 100.00 MB
# UsedSpace          : 3.38 MB
# AvailableSpace     : 96.62 MB
# NumberOfDiskWrites : 17415
# NumberOfDiskReads  : 828
# ReadFromDisk       : 82.29 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DBAdmin
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : DBAdmin_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DBAdmin_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 72.00 MB
# UsedSpace          : 13.39 MB
# AvailableSpace     : 58.61 MB
# NumberOfDiskWrites : 4413
# NumberOfDiskReads  : 791
# ReadFromDisk       : 3.29 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WWI_DC2
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : WorldWideImporters_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WWI_DC2_Primary.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 9.77 MB
# AvailableSpace     : 118.23 MB
# NumberOfDiskWrites : 5122
# NumberOfDiskReads  : 870
# ReadFromDisk       : 94.70 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : relog
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : relog_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\relog_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 392.00 MB
# UsedSpace          : 14.45 MB
# AvailableSpace     : 377.55 MB
# NumberOfDiskWrites : 4412
# NumberOfDiskReads  : 811
# ReadFromDisk       : 3.36 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : PerfmonData
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : PerfmonData_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\PerfmonData_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 200.00 MB
# UsedSpace          : 8.28 MB
# AvailableSpace     : 191.72 MB
# NumberOfDiskWrites : 4412
# NumberOfDiskReads  : 799
# ReadFromDisk       : 3.32 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : UatDatabase
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : UatDatabase_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\UatDatabase_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 1.36 MB
# AvailableSpace     : 6.64 MB
# NumberOfDiskWrites : 4409
# NumberOfDiskReads  : 780
# ReadFromDisk       : 3.20 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : PurgeTest
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : PurgeTest_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\PurgeTest_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 200.00 MB
# UsedSpace          : 11.73 MB
# AvailableSpace     : 188.27 MB
# NumberOfDiskWrites : 3792
# NumberOfDiskReads  : 626
# ReadFromDisk       : 2.63 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : BackupTest_Copy
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : BackupTest_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\BackupTest_Copy_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 11.88 MB
# AvailableSpace     : 116.12 MB
# NumberOfDiskWrites : 4414
# NumberOfDiskReads  : 791
# ReadFromDisk       : 3.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : AuditDatabase
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : AuditDatabase_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\AuditDatabase_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 1.49 MB
# AvailableSpace     : 6.51 MB
# NumberOfDiskWrites : 4412
# NumberOfDiskReads  : 788
# ReadFromDisk       : 3.26 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : AssessmentInventory
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : AssessmentInventory_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\AssessmentInventory_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.12 MB
# AvailableSpace     : 5.88 MB
# NumberOfDiskWrites : 4416
# NumberOfDiskReads  : 788
# ReadFromDisk       : 2.44 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : BackupTest
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : BackupTest_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\BackupTest_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 12.04 MB
# AvailableSpace     : 115.96 MB
# NumberOfDiskWrites : 4413
# NumberOfDiskReads  : 791
# ReadFromDisk       : 3.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DataMasking
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : DataMasking_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DataMasking_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 12.72 MB
# AvailableSpace     : 115.28 MB
# NumberOfDiskWrites : 4410
# NumberOfDiskReads  : 791
# ReadFromDisk       : 3.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DB1024LOG
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : DB1024LOG_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DB1024LOG_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 1048576
# GrowthType         : kb
# Size               : 1.12 GB
# UsedSpace          : 11.77 MB
# AvailableSpace     : 1.11 GB
# NumberOfDiskWrites : 4414
# NumberOfDiskReads  : 799
# ReadFromDisk       : 3.30 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DB256LOG
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : DB256LOG_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DB256LOG_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 262144
# GrowthType         : kb
# Size               : 896.00 MB
# UsedSpace          : 26.42 MB
# AvailableSpace     : 869.58 MB
# NumberOfDiskWrites : 4412
# NumberOfDiskReads  : 815
# ReadFromDisk       : 3.37 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : dbChangeTrackingMetadata
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : dbChangeTrackingMetadata_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\dbChangeTrackingMetadata_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.22 MB
# AvailableSpace     : 5.78 MB
# NumberOfDiskWrites : 4409
# NumberOfDiskReads  : 787
# ReadFromDisk       : 3.26 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : difffileloc
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : difffileloc_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\difffileloc_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 11.72 MB
# AvailableSpace     : 116.28 MB
# NumberOfDiskWrites : 4410
# NumberOfDiskReads  : 791
# ReadFromDisk       : 3.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DMAReporting
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : DMAReporting_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DMAReporting_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.24 MB
# AvailableSpace     : 5.76 MB
# NumberOfDiskWrites : 4412
# NumberOfDiskReads  : 787
# ReadFromDisk       : 3.26 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DMAReportingTest
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : DMAReportingTest_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DMAReportingTest_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.23 MB
# AvailableSpace     : 5.77 MB
# NumberOfDiskWrites : 4410
# NumberOfDiskReads  : 787
# ReadFromDisk       : 3.26 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DMAWarehouse
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : DMAWarehouse_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DMAWarehouse_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 200.00 MB
# UsedSpace          : 21.10 MB
# AvailableSpace     : 178.90 MB
# NumberOfDiskWrites : 4410
# NumberOfDiskReads  : 791
# ReadFromDisk       : 3.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DMAWarehouseTest
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : DMAWarehouseTest_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DMAWarehouseTest_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 200.00 MB
# UsedSpace          : 12.30 MB
# AvailableSpace     : 187.70 MB
# NumberOfDiskWrites : 4409
# NumberOfDiskReads  : 791
# ReadFromDisk       : 3.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : HealthCheckResults
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : HealthCheckResults_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\HealthCheckResults_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 264.00 MB
# UsedSpace          : 7.23 MB
# AvailableSpace     : 256.77 MB
# NumberOfDiskWrites : 4411
# NumberOfDiskReads  : 803
# ReadFromDisk       : 3.33 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : Lahman
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : Lahman_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\Lahman_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 192.00 MB
# UsedSpace          : 6.25 MB
# AvailableSpace     : 185.75 MB
# NumberOfDiskWrites : 4411
# NumberOfDiskReads  : 795
# ReadFromDisk       : 3.29 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : MAP_SampleDB
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : MAP_SampleDB_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\MAP_SampleDB_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 1048576
# GrowthType         : kb
# Size               : 82.44 MB
# UsedSpace          : 4.23 MB
# AvailableSpace     : 78.20 MB
# NumberOfDiskWrites : 5127
# NumberOfDiskReads  : 912
# ReadFromDisk       : 3.61 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : ProdDb
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : ProdDb_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\ProdDb_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 13.87 MB
# AvailableSpace     : 114.13 MB
# NumberOfDiskWrites : 4415
# NumberOfDiskReads  : 791
# ReadFromDisk       : 3.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : DMAInventory
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : DMAInventory_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\DMAInventory_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 1.28 MB
# AvailableSpace     : 6.72 MB
# NumberOfDiskWrites : 4412
# NumberOfDiskReads  : 788
# ReadFromDisk       : 3.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : TestDatabaseProject
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : TestDatabaseProject_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\TestDatabaseProject_Primary.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 320.00 MB
# UsedSpace          : 318.56 MB
# AvailableSpace     : 1.44 MB
# NumberOfDiskWrites : 17442
# NumberOfDiskReads  : 6570
# ReadFromDisk       : 5.12 GB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : TestReporting
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : TestReporting_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\TestReporting_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.09 MB
# AvailableSpace     : 5.91 MB
# NumberOfDiskWrites : 4414
# NumberOfDiskReads  : 781
# ReadFromDisk       : 2.55 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : TestWarehouse
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : TestWarehouse_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\TestWarehouse_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 1.02 MB
# AvailableSpace     : 6.98 MB
# NumberOfDiskWrites : 4414
# NumberOfDiskReads  : 780
# ReadFromDisk       : 3.22 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : backuptesting
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : backuptesting_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\backuptesting_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 72.00 MB
# UsedSpace          : 2.28 MB
# AvailableSpace     : 69.72 MB
# NumberOfDiskWrites : 4413
# NumberOfDiskReads  : 792
# ReadFromDisk       : 2.44 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb1
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : testdb1_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb1_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.19 MB
# AvailableSpace     : 5.81 MB
# NumberOfDiskWrites : 4413
# NumberOfDiskReads  : 784
# ReadFromDisk       : 3.23 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb2
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : testdb2_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb2_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.19 MB
# AvailableSpace     : 5.81 MB
# NumberOfDiskWrites : 4411
# NumberOfDiskReads  : 785
# ReadFromDisk       : 3.23 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb3
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : testdb3_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb3_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.19 MB
# AvailableSpace     : 5.81 MB
# NumberOfDiskWrites : 4412
# NumberOfDiskReads  : 785
# ReadFromDisk       : 3.23 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb4
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : testdb4_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb4_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.19 MB
# AvailableSpace     : 5.81 MB
# NumberOfDiskWrites : 4411
# NumberOfDiskReads  : 785
# ReadFromDisk       : 3.23 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb5
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : testdb5_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb5_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.19 MB
# AvailableSpace     : 5.81 MB
# NumberOfDiskWrites : 4413
# NumberOfDiskReads  : 785
# ReadFromDisk       : 2.30 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb6
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : testdb6_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb6_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.18 MB
# AvailableSpace     : 5.82 MB
# NumberOfDiskWrites : 4412
# NumberOfDiskReads  : 784
# ReadFromDisk       : 2.32 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb7
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : testdb7_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb7_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.17 MB
# AvailableSpace     : 5.83 MB
# NumberOfDiskWrites : 4414
# NumberOfDiskReads  : 785
# ReadFromDisk       : 2.33 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb8
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : testdb8_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb8_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.18 MB
# AvailableSpace     : 5.82 MB
# NumberOfDiskWrites : 4410
# NumberOfDiskReads  : 785
# ReadFromDisk       : 2.32 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb9
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : testdb9_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb9_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 2.19 MB
# AvailableSpace     : 5.81 MB
# NumberOfDiskWrites : 4412
# NumberOfDiskReads  : 784
# ReadFromDisk       : 2.30 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : TestDBA
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : TestDBA_log1
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\TestDBA_log1.ldf
# MaxSize            : 2.00 TB
# Growth             : 131072
# GrowthType         : kb
# Size               : 2.00 MB
# UsedSpace          : 728.00 KB
# AvailableSpace     : 1.29 MB
# NumberOfDiskWrites : 4421
# NumberOfDiskReads  : 790
# ReadFromDisk       : 2.64 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : TranAnatomy
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : TranAnatomy_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\TranAnatomy_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 11.79 MB
# AvailableSpace     : 116.21 MB
# NumberOfDiskWrites : 4411
# NumberOfDiskReads  : 783
# ReadFromDisk       : 3.21 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : UatDb
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : UatDb_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\UatDb_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 9.88 MB
# AvailableSpace     : 118.12 MB
# NumberOfDiskWrites : 4410
# NumberOfDiskReads  : 783
# ReadFromDisk       : 3.21 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : WorldWideImporters
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : WorldWideImporters_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\WorldWideImporters_Primary.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 16.95 MB
# AvailableSpace     : 111.05 MB
# NumberOfDiskWrites : 5122
# NumberOfDiskReads  : 1046
# ReadFromDisk       : 242.62 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : BackupTest_copy_03052020
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : BackupTest_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\BackupTest_copy_03052020_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 11.88 MB
# AvailableSpace     : 116.12 MB
# NumberOfDiskWrites : 4410
# NumberOfDiskReads  : 791
# ReadFromDisk       : 3.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : BackupTest_copy_03052020_113500
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : BackupTest_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\BackupTest_copy_03052020_113500_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 11.88 MB
# AvailableSpace     : 116.12 MB
# NumberOfDiskWrites : 4410
# NumberOfDiskReads  : 791
# ReadFromDisk       : 3.27 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : SmalLog_copy_03052020_113900
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : SmalLog_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\SmalLog_copy_03052020_113900_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 1.06 GB
# UsedSpace          : 39.83 MB
# AvailableSpace     : 1.02 GB
# NumberOfDiskWrites : 4411
# NumberOfDiskReads  : 797
# ReadFromDisk       : 3.30 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : UatDb_copy_03092020_151500
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : ProdDb_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\UatDb_copy_03092020_151500_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 15.43 MB
# AvailableSpace     : 112.57 MB
# NumberOfDiskWrites : 4410
# NumberOfDiskReads  : 784
# ReadFromDisk       : 3.22 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2017
# Database           : testdb_copy_03052020_113900
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : ProdDb_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL14.DEV2017\MSSQL\DATA\testdb_copy_03052020_113900_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 15.43 MB
# AvailableSpace     : 112.57 MB
# NumberOfDiskWrites : 4411
# NumberOfDiskReads  : 789
# ReadFromDisk       : 3.26 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : master
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : mastlog
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\mastlog.ldf
# MaxSize            : Unlimited
# Growth             : 1048576
# GrowthType         : kb
# Size               : 1.06 GB
# UsedSpace          : 4.07 MB
# AvailableSpace     : 1.05 GB
# NumberOfDiskWrites : 33817
# NumberOfDiskReads  : 81
# ReadFromDisk       : 1.73 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : tempdb
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : templog
# PhysicalName       : C:\temp\tempdb\templog.ldf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 816.00 KB
# AvailableSpace     : 7.20 MB
# NumberOfDiskWrites : 19640
# NumberOfDiskReads  : 26
# ReadFromDisk       : 1.11 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : model
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : modellog
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\modellog.ldf
# MaxSize            : Unlimited
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 1.65 MB
# AvailableSpace     : 126.35 MB
# NumberOfDiskWrites : 10
# NumberOfDiskReads  : 17
# ReadFromDisk       : 1,024.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : msdb
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : MSDBLog
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\MSDBLog.ldf
# MaxSize            : 2.00 TB
# Growth             : 1048576
# GrowthType         : kb
# Size               : 19.62 MB
# UsedSpace          : 1.41 MB
# AvailableSpace     : 18.22 MB
# NumberOfDiskWrites : 93628
# NumberOfDiskReads  : 83
# ReadFromDisk       : 1.19 MB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : AssessmentInventory
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : AssessmentInventory_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\AssessmentInventory_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 1.09 MB
# AvailableSpace     : 6.91 MB
# NumberOfDiskWrites : 6
# NumberOfDiskReads  : 7
# ReadFromDisk       : 984.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : SmalLog
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : SmalLog_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\SmalLog_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 1.06 GB
# UsedSpace          : 29.08 MB
# AvailableSpace     : 1.04 GB
# NumberOfDiskWrites : 7
# NumberOfDiskReads  : 17
# ReadFromDisk       : 1,024.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : Baselines
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : Baselines_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\Baselines_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 3.12 MB
# AvailableSpace     : 124.88 MB
# NumberOfDiskWrites : 6
# NumberOfDiskReads  : 11
# ReadFromDisk       : 1,000.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : ProdDb
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : ProdDb_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\ProdDb_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 4.84 MB
# AvailableSpace     : 123.16 MB
# NumberOfDiskWrites : 6
# NumberOfDiskReads  : 11
# ReadFromDisk       : 1,000.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : PvNoneDb
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : PvNoneDb_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\PvNoneDb_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 25600
# GrowthType         : kb
# Size               : 25.00 MB
# UsedSpace          : 5.70 MB
# AvailableSpace     : 19.30 MB
# NumberOfDiskWrites : 5
# NumberOfDiskReads  : 7
# ReadFromDisk       : 984.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : PvTornPageDb
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : PvTornPageDb_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\PvTornPageDb_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 25600
# GrowthType         : kb
# Size               : 25.00 MB
# UsedSpace          : 5.70 MB
# AvailableSpace     : 19.30 MB
# NumberOfDiskWrites : 6
# NumberOfDiskReads  : 7
# ReadFromDisk       : 984.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : PvCheckSumDb
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : PvCheckSumDb_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\PvCheckSumDb_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 25600
# GrowthType         : kb
# Size               : 25.00 MB
# UsedSpace          : 5.69 MB
# AvailableSpace     : 19.31 MB
# NumberOfDiskWrites : 6
# NumberOfDiskReads  : 7
# ReadFromDisk       : 984.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : PerfmonTest
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : PerfmonTest_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\PerfmonTest_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 736.00 KB
# AvailableSpace     : 127.28 MB
# NumberOfDiskWrites : 6
# NumberOfDiskReads  : 11
# ReadFromDisk       : 1,000.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : DefaultConstraint
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : DefaultConstraint_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\DefaultConstraint_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 624.00 KB
# AvailableSpace     : 127.39 MB
# NumberOfDiskWrites : 7
# NumberOfDiskReads  : 11
# ReadFromDisk       : 1,000.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : ASPState
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : ASPState_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\ASPState_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 8.00 MB
# UsedSpace          : 824.00 KB
# AvailableSpace     : 7.20 MB
# NumberOfDiskWrites : 5
# NumberOfDiskReads  : 7
# ReadFromDisk       : 984.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : TestDB
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : TestDB_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\DATA\TestDB_log.ldf
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 128.00 MB
# UsedSpace          : 608.00 KB
# AvailableSpace     : 127.41 MB
# NumberOfDiskWrites : 6
# NumberOfDiskReads  : 11
# ReadFromDisk       : 1,000.00 KB
# WritesToDisk       :
#
# SqlInstance        : DESKTOP-1KGJIH9\DEV2016
# Database           : distribution
# FileGroupName      :
# TypeDescription    : LOG
# LogicalName        : distribution_log
# PhysicalName       : C:\Program Files\Microsoft SQL Server\MSSQL13.DEV2016\MSSQL\Data\distribution.LDF
# MaxSize            : 2.00 TB
# Growth             : 65536
# GrowthType         : kb
# Size               : 129.00 MB
# UsedSpace          : 2.99 MB
# AvailableSpace     : 126.01 MB
# NumberOfDiskWrites : 6
# NumberOfDiskReads  : 11
# ReadFromDisk       : 1,000.00 KB
# WritesToDisk       :

# %% [markdown]
# # Chapter 6

# %% [markdown]
# # Get sys.configuration Settings
# This code returns the value and value_in_use from the sys.configuration table for an instance of SQL Server.

# %%
$instances = Get-Content -Path C:\Users\fgill\Documents\GitHub\AzureDataStudioAndContainers\instances.txt;

foreach ($instance in $instances)
{
    $configs = Get-DbaSpConfigure -SqlInstance $instance | Select-Object -Property Name, ConfiguredValue, RunningValue | Sort-Object -Property Name;
    foreach($config in $configs)
    {
        $configout = New-Object -TypeName psobject;
        $configout | Add-Member -MemberType NoteProperty -Name SqlInstance -Value $instance;
        $configout | Add-Member -MemberType NoteProperty -Name Configuration -Value $config.Name;
        $configout | Add-Member -MemberType NoteProperty -Name Value -Value $config.ConfiguredValue;
        $configout | Add-Member -MemberType NoteProperty -Name ValueInUse -Value $config.RunningValue;
        $configout;
    }
}
# Out:
# SqlInstance       Configuration                   Value ValueInUse
# -----------       -------------                   ----- ----------
# localhost\dev2017 AccessCheckCacheBucketCount         0          0
# localhost\dev2017 AccessCheckCacheQuota               0          0
# localhost\dev2017 AdHocDistributedQueriesEnabled      0          0
# localhost\dev2017 Affinity64IOMask                    0          0
# localhost\dev2017 Affinity64Mask                      0          0
# localhost\dev2017 AffinityIOMask                      0          0
# localhost\dev2017 AffinityMask                        0          0
# localhost\dev2017 AgentXPsEnabled                     1          1
# localhost\dev2017 AllowPolybaseExport                 0          0
# localhost\dev2017 AllowUpdates                        0          0
# localhost\dev2017 AutomaticSoftnumaDisabled           0          0
# localhost\dev2017 BackupChecksumDefault               0          0
# localhost\dev2017 BlockedProcessThreshold             0          0
# localhost\dev2017 C2AuditMode                         0          0
# localhost\dev2017 ClrStrictSecurity                   1          1
# localhost\dev2017 CommonCriteriaComplianceEnabled     0          0
# localhost\dev2017 ContainmentEnabled                  0          0
# localhost\dev2017 CostThresholdForParallelism         5          5
# localhost\dev2017 CrossDBOwnershipChaining            0          0
# localhost\dev2017 CursorThreshold                    -1         -1
# localhost\dev2017 DatabaseMailEnabled                 1          1
# localhost\dev2017 DefaultBackupCompression            1          1
# localhost\dev2017 DefaultFullTextLanguage          1033       1033
# localhost\dev2017 DefaultLanguage                     0          0
# localhost\dev2017 DefaultTraceEnabled                 1          1
# localhost\dev2017 DisallowResultsFromTriggers         0          0
# localhost\dev2017 ExtensibleKeyManagementEnabled      0          0
# localhost\dev2017 ExternalScriptsEnabled              0          0
# localhost\dev2017 FilestreamAccessLevel               0          0
# localhost\dev2017 FillFactor                          0          0
# localhost\dev2017 FullTextCrawlBandwidthMax         100        100
# localhost\dev2017 FullTextCrawlBandwidthMin           0          0
# localhost\dev2017 FullTextCrawlRangeMax               4          4
# localhost\dev2017 FullTextNotifyBandwidthMax        100        100
# localhost\dev2017 FullTextNotifyBandwidthMin          0          0
# localhost\dev2017 HadoopConnectivity                  0          0
# localhost\dev2017 IndexCreateMemory                   0          0
# localhost\dev2017 InDoubtTransactionResolution        0          0
# localhost\dev2017 IsSqlClrEnabled                     0          0
# localhost\dev2017 LightweightPooling                  0          0
# localhost\dev2017 Locks                               0          0
# localhost\dev2017 MaxDegreeOfParallelism              0          0
# localhost\dev2017 MaxServerMemory                 25600      25600
# localhost\dev2017 MaxWorkerThreads                    0          0
# localhost\dev2017 MediaRetention                      0          0
# localhost\dev2017 MinMemoryPerQuery                1024       1024
# localhost\dev2017 MinServerMemory                     0         16
# localhost\dev2017 NestedTriggers                      1          1
# localhost\dev2017 NetworkPacketSize                4096       4096
# localhost\dev2017 OleAutomationProceduresEnabled      0          0
# localhost\dev2017 OpenObjects                         0          0
# localhost\dev2017 OptimizeAdhocWorkloads              0          0
# localhost\dev2017 PolybaseNetworkEncryption           1          1
# localhost\dev2017 PrecomputeRank                      0          0
# localhost\dev2017 PriorityBoost                       0          0
# localhost\dev2017 ProtocolHandlerTimeout             60         60
# localhost\dev2017 QueryGovernorCostLimit              0          0
# localhost\dev2017 QueryWait                          -1         -1
# localhost\dev2017 RecoveryInterval                    0          0
# localhost\dev2017 RemoteAccess                        1          1
# localhost\dev2017 RemoteDacConnectionsEnabled         0          0
# localhost\dev2017 RemoteDataArchiveEnabled            0          0
# localhost\dev2017 RemoteLoginTimeout                 10         10
# localhost\dev2017 RemoteProcTrans                     0          0
# localhost\dev2017 RemoteQueryTimeout                600        600
# localhost\dev2017 ReplicationMaxTextSize          65536      65536
# localhost\dev2017 ReplicationXPsEnabled               0          0
# localhost\dev2017 ScanForStartupProcedures            1          1
# localhost\dev2017 ServerTriggerRecursionEnabled       1          1
# localhost\dev2017 SetWorkingSetSize                   0          0
# localhost\dev2017 ShowAdvancedOptions                 1          1
# localhost\dev2017 SmoAndDmoXPsEnabled                 1          1
# localhost\dev2017 TransformNoiseWords                 0          0
# localhost\dev2017 TwoDigitYearCutoff               2049       2049
# localhost\dev2017 UserConnections                     0          0
# localhost\dev2017 UserOptions                         0          0
# localhost\dev2017 XPCmdShellEnabled                   1          1
# localhost\dev2016 AccessCheckCacheBucketCount         0          0
# localhost\dev2016 AccessCheckCacheQuota               0          0
# localhost\dev2016 AdHocDistributedQueriesEnabled      0          0
# localhost\dev2016 Affinity64IOMask                    0          0
# localhost\dev2016 Affinity64Mask                      0          0
# localhost\dev2016 AffinityIOMask                      0          0
# localhost\dev2016 AffinityMask                        0          0
# localhost\dev2016 AgentXPsEnabled                     1          1
# localhost\dev2016 AllowPolybaseExport                 0          0
# localhost\dev2016 AllowUpdates                        0          0
# localhost\dev2016 AutomaticSoftnumaDisabled           0          0
# localhost\dev2016 BackupChecksumDefault               0          0
# localhost\dev2016 BlockedProcessThreshold             0          0
# localhost\dev2016 C2AuditMode                         0          0
# localhost\dev2016 CommonCriteriaComplianceEnabled     0          0
# localhost\dev2016 ContainmentEnabled                  0          0
# localhost\dev2016 CostThresholdForParallelism         5          5
# localhost\dev2016 CrossDBOwnershipChaining            0          0
# localhost\dev2016 CursorThreshold                    -1         -1
# localhost\dev2016 DatabaseMailEnabled                 0          0
# localhost\dev2016 DefaultBackupCompression            1          1
# localhost\dev2016 DefaultFullTextLanguage          1033       1033
# localhost\dev2016 DefaultLanguage                     0          0
# localhost\dev2016 DefaultTraceEnabled                 1          1
# localhost\dev2016 DisallowResultsFromTriggers         0          0
# localhost\dev2016 ExtensibleKeyManagementEnabled      0          0
# localhost\dev2016 ExternalScriptsEnabled              0          0
# localhost\dev2016 FilestreamAccessLevel               0          0
# localhost\dev2016 FillFactor                          0          0
# localhost\dev2016 FullTextCrawlBandwidthMax         100        100
# localhost\dev2016 FullTextCrawlBandwidthMin           0          0
# localhost\dev2016 FullTextCrawlRangeMax               4          4
# localhost\dev2016 FullTextNotifyBandwidthMax        100        100
# localhost\dev2016 FullTextNotifyBandwidthMin          0          0
# localhost\dev2016 HadoopConnectivity                  0          0
# localhost\dev2016 IndexCreateMemory                   0          0
# localhost\dev2016 InDoubtTransactionResolution        0          0
# localhost\dev2016 IsSqlClrEnabled                     0          0
# localhost\dev2016 LightweightPooling                  0          0
# localhost\dev2016 Locks                               0          0
# localhost\dev2016 MaxDegreeOfParallelism              0          0
# localhost\dev2016 MaxServerMemory                 25600      25600
# localhost\dev2016 MaxWorkerThreads                    0          0
# localhost\dev2016 MediaRetention                      0          0
# localhost\dev2016 MinMemoryPerQuery                1024       1024
# localhost\dev2016 MinServerMemory                     0         16
# localhost\dev2016 NestedTriggers                      1          1
# localhost\dev2016 NetworkPacketSize                4096       4096
# localhost\dev2016 OleAutomationProceduresEnabled      0          0
# localhost\dev2016 OpenObjects                         0          0
# localhost\dev2016 OptimizeAdhocWorkloads              0          0
# localhost\dev2016 PolybaseNetworkEncryption           1          1
# localhost\dev2016 PrecomputeRank                      0          0
# localhost\dev2016 PriorityBoost                       0          0
# localhost\dev2016 ProtocolHandlerTimeout             60         60
# localhost\dev2016 QueryGovernorCostLimit              0          0
# localhost\dev2016 QueryWait                          -1         -1
# localhost\dev2016 RecoveryInterval                    0          0
# localhost\dev2016 RemoteAccess                        1          1
# localhost\dev2016 RemoteDacConnectionsEnabled         0          0
# localhost\dev2016 RemoteDataArchiveEnabled            0          0
# localhost\dev2016 RemoteLoginTimeout                 10         10
# localhost\dev2016 RemoteProcTrans                     0          0
# localhost\dev2016 RemoteQueryTimeout                600        600
# localhost\dev2016 ReplicationMaxTextSize          65536      65536
# localhost\dev2016 ReplicationXPsEnabled               0          0
# localhost\dev2016 ScanForStartupProcedures            1          1
# localhost\dev2016 ServerTriggerRecursionEnabled       1          1
# localhost\dev2016 SetWorkingSetSize                   0          0
# localhost\dev2016 ShowAdvancedOptions                 1          1
# localhost\dev2016 SmoAndDmoXPsEnabled                 1          1
# localhost\dev2016 TransformNoiseWords                 0          0
# localhost\dev2016 TwoDigitYearCutoff               2049       2049
# localhost\dev2016 UserConnections                     0          0
# localhost\dev2016 UserOptions                         0          0
# localhost\dev2016 XPCmdShellEnabled                   1          1

# %% [markdown]
# # Chapter 7

# %% [markdown]
# # Get SQL Agent Alerts
# This code return all existing SQL Agent alerts for a SQL Server instance.

# %%
$instances = Get-Content -Path C:\Users\fgill\Documents\GitHub\AzureDataStudioAndContainers\instances.txt;

foreach ($instance in $instances)
{
    $alerts = Get-DbaAgentAlert -SqlInstance $instance;
    foreach($alert in $alerts)
    {
        $instancealert = New-Object -TypeName psobject;
        $instancealert | Add-Member -MemberType NoteProperty -Name SqlInstance -Value $instance;
        $instancealert | Add-Member -MemberType NoteProperty -Name AlertName -Value $alert;
        $instancealert;
    }
}
# Out:
# SqlInstance       AlertName
# -----------       ---------
# localhost\dev2017 [SQL Server Alerting -  Error 1205]
# localhost\dev2017 [SQL Server Alerting -  Error 14151]
# localhost\dev2017 [SQL Server Alerting -  Error 17806]
# localhost\dev2017 [SQL Server Alerting -  Error 17836]
# localhost\dev2017 [SQL Server Alerting -  Error 18056]
# localhost\dev2017 [SQL Server Alerting -  Error 18210]
# localhost\dev2017 [SQL Server Alerting -  Error 18456]
# localhost\dev2017 [SQL Server Alerting -  Error 4014]
# localhost\dev2017 [SQL Server Alerting -  Error 701]
# localhost\dev2017 [SQL Server Alerting -  Error 7886]
# localhost\dev2017 [SQL Server Alerting -  Error 825]
# localhost\dev2017 [SQL Server Alerting -  Error 9002]
# localhost\dev2017 [SQL Server Alerting - Severity 019]
# localhost\dev2017 [SQL Server Alerting - Severity 020]
# localhost\dev2017 [SQL Server Alerting - Severity 021]
# localhost\dev2017 [SQL Server Alerting - Severity 022]
# localhost\dev2017 [SQL Server Alerting - Severity 023]
# localhost\dev2017 [SQL Server Alerting - Severity 024]
# localhost\dev2017 [SQL Server Alerting - Severity 025]
# localhost\dev2016 [Peer-to-peer conflict detection alert]
# localhost\dev2016 [Replication Warning: Long merge over …
# localhost\dev2016 [Replication Warning: Long merge over …
# localhost\dev2016 [Replication Warning: Slow merge over …
# localhost\dev2016 [Replication Warning: Slow merge over …
# localhost\dev2016 [Replication Warning: Subscription exp…
# localhost\dev2016 [Replication Warning: Transactional re…
# localhost\dev2016 [Replication: agent custom shutdown]
# localhost\dev2016 [Replication: agent failure]
# localhost\dev2016 [Replication: agent retry]
# localhost\dev2016 [Replication: agent success]
# localhost\dev2016 [Replication: expired subscription dro…
# localhost\dev2016 [Replication: Subscriber has failed da…
# localhost\dev2016 [Replication: Subscriber has passed da…
# localhost\dev2016 [Replication: Subscription reinitializ…
# localhost\dev2016 [SQL Server Alerting -  Error 1205 - D…
# localhost\dev2016 [SQL Server Alerting -  Error 17806 - …
# localhost\dev2016 [SQL Server Alerting -  Error 17836]
# localhost\dev2016 [SQL Server Alerting -  Error 18056 - …
# localhost\dev2016 [SQL Server Alerting -  Error 18210 - …
# localhost\dev2016 [SQL Server Alerting -  Error 4014 - I…
# localhost\dev2016 [SQL Server Alerting -  Error 701 - In…
# localhost\dev2016 [SQL Server Alerting -  Error 7886 - R…
# localhost\dev2016 [SQL Server Alerting -  Error 825 - IO…
# localhost\dev2016 [SQL Server Alerting -  Error 9002 - T…
# localhost\dev2016 [SQL Server Alerting - Severity 019]
# localhost\dev2016 [SQL Server Alerting - Severity 020]
# localhost\dev2016 [SQL Server Alerting - Severity 021]
# localhost\dev2016 [SQL Server Alerting - Severity 022]
# localhost\dev2016 [SQL Server Alerting - Severity 023]
# localhost\dev2016 [SQL Server Alerting - Severity 024]
# localhost\dev2016 [SQL Server Alerting - Severity 025]

# %% [markdown]
# # Chapter 8

# %% [markdown]
# # Get Wait Stats
# This code returns wait stats for a SQL Server instance sorted by percentage descending.

# %%
$instances = Get-Content -Path C:\Users\fgill\Documents\GitHub\AzureDataStudioAndContainers\instances.txt;

foreach ($instance in $instances)
{
    $waitstats = Get-DbaWaitStatistic -SqlInstance $instance;
    foreach($waitstat in $waitstats)
    {
         $instancewait = New-Object -TypeName psobject;
         $instancewait | Add-Member -MemberType NoteProperty -Name SqlInstance -Value $instance;
         $instancewait | Add-Member -MemberType NoteProperty -Name Category -Value $waitstat.Category;
         $instancewait | Add-Member -MemberType NoteProperty -Name WaitType -Value $waitstat.WaitType;
         $instancewait | Add-Member -MemberType NoteProperty -Name Percentage -Value $waitstat.Percentage;
         $instancewait | Add-Member -MemberType NoteProperty -Name WaitCount -Value $waitstat.WaitCount;
         $instancewait | Add-Member -MemberType NoteProperty -Name WaitSeconds -Value $waitstat.WaitSeconds;
         $instancewait | Add-Member -MemberType NoteProperty -Name ResourceSeconds -Value $waitstat.ResourceSeconds;
         $instancewait | Add-Member -MemberType NoteProperty -Name SignalSeconds -Value $waitstat.SignalSeconds;
         $instancewait | Add-Member -MemberType NoteProperty -Name AvgWaitSeconds -Value $waitstat.AverageWaitSeconds;
         $instancewait | Add-Member -MemberType NoteProperty -Name AvgResourceSeconds -Value $waitstat.AverageResourceSeconds;
         $instancewait | Add-Member -MemberType NoteProperty -Name AvgSignalSeconds -Value $waitstat.AverageSignalSeconds;

         $instancewait | Sort-Object -Property Percentage -Descending;

    }
}
# Out:
# SqlInstance        : localhost\dev2017
# Category           : Network I/O
# WaitType           : OLEDB
# Percentage         : 24.64
# WaitCount          : 15701955
# WaitSeconds        : 1757.91
# ResourceSeconds    : 1757.91
# SignalSeconds      : 0.00
# AvgWaitSeconds     : 0.0001
# AvgResourceSeconds : 0.0001
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2017
# Category           : Buffer IO
# WaitType           : PAGEIOLATCH_SH
# Percentage         : 16.69
# WaitCount          : 262931
# WaitSeconds        : 1190.61
# ResourceSeconds    : 1155.76
# SignalSeconds      : 34.86
# AvgWaitSeconds     : 0.0045
# AvgResourceSeconds : 0.0044
# AvgSignalSeconds   : 0.0001
#
# SqlInstance        : localhost\dev2017
# Category           : Backup
# WaitType           : BACKUPTHREAD
# Percentage         : 13.50
# WaitCount          : 856595
# WaitSeconds        : 962.91
# ResourceSeconds    : 924.37
# SignalSeconds      : 38.54
# AvgWaitSeconds     : 0.0011
# AvgResourceSeconds : 0.0011
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2017
# Category           : Parallelism
# WaitType           : CXPACKET
# Percentage         : 11.17
# WaitCount          : 368117
# WaitSeconds        : 797.02
# ResourceSeconds    : 750.24
# SignalSeconds      : 46.78
# AvgWaitSeconds     : 0.0022
# AvgResourceSeconds : 0.0020
# AvgSignalSeconds   : 0.0001
#
# SqlInstance        : localhost\dev2017
# Category           : Other Disk IO
# WaitType           : BACKUPIO
# Percentage         : 5.99
# WaitCount          : 1708900
# WaitSeconds        : 427.26
# ResourceSeconds    : 389.71
# SignalSeconds      : 37.55
# AvgWaitSeconds     : 0.0003
# AvgResourceSeconds : 0.0002
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2017
# Category           : Tran Log IO
# WaitType           : WRITELOG
# Percentage         : 3.89
# WaitCount          : 513976
# WaitSeconds        : 277.55
# ResourceSeconds    : 244.00
# SignalSeconds      : 33.55
# AvgWaitSeconds     : 0.0005
# AvgResourceSeconds : 0.0005
# AvgSignalSeconds   : 0.0001
#
# SqlInstance        : localhost\dev2017
# Category           : Preemptive
# WaitType           : PREEMPTIVE_OS_CREATEFILE
# Percentage         : 3.84
# WaitCount          : 255885
# WaitSeconds        : 274.03
# ResourceSeconds    : 274.03
# SignalSeconds      : 0.00
# AvgWaitSeconds     : 0.0011
# AvgResourceSeconds : 0.0011
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2017
# Category           : Backup
# WaitType           : BACKUPBUFFER
# Percentage         : 2.55
# WaitCount          : 142642
# WaitSeconds        : 181.81
# ResourceSeconds    : 177.01
# SignalSeconds      : 4.79
# AvgWaitSeconds     : 0.0013
# AvgResourceSeconds : 0.0012
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2017
# Category           : Other Disk IO
# WaitType           : ASYNC_IO_COMPLETION
# Percentage         : 2.23
# WaitCount          : 4176
# WaitSeconds        : 158.93
# ResourceSeconds    : 158.56
# SignalSeconds      : 0.37
# AvgWaitSeconds     : 0.0381
# AvgResourceSeconds : 0.0380
# AvgSignalSeconds   : 0.0001
#
# SqlInstance        : localhost\dev2017
# Category           : Worker Thread
# WaitType           : THREADPOOL
# Percentage         : 1.79
# WaitCount          : 100907
# WaitSeconds        : 127.79
# ResourceSeconds    : 127.77
# SignalSeconds      : 0.02
# AvgWaitSeconds     : 0.0013
# AvgResourceSeconds : 0.0013
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2017
# Category           : CPU
# WaitType           : SOS_SCHEDULER_YIELD
# Percentage         : 1.57
# WaitCount          : 1876291
# WaitSeconds        : 112.26
# ResourceSeconds    : 1.81
# SignalSeconds      : 110.45
# AvgWaitSeconds     : 0.0001
# AvgResourceSeconds : 0.0000
# AvgSignalSeconds   : 0.0001
#
# SqlInstance        : localhost\dev2017
# Category           : Other
# WaitType           : MSQL_XP
# Percentage         : 1.40
# WaitCount          : 65409
# WaitSeconds        : 99.91
# ResourceSeconds    : 99.91
# SignalSeconds      : 0.00
# AvgWaitSeconds     : 0.0015
# AvgResourceSeconds : 0.0015
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2017
# Category           : Preemptive
# WaitType           : PREEMPTIVE_OS_FLUSHFILEBUFFERS
# Percentage         : 1.39
# WaitCount          : 39015
# WaitSeconds        : 99.28
# ResourceSeconds    : 99.28
# SignalSeconds      : 0.00
# AvgWaitSeconds     : 0.0025
# AvgResourceSeconds : 0.0025
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2017
# Category           : Latch
# WaitType           : LATCH_EX
# Percentage         : 1.31
# WaitCount          : 206154
# WaitSeconds        : 93.50
# ResourceSeconds    : 60.93
# SignalSeconds      : 32.56
# AvgWaitSeconds     : 0.0005
# AvgResourceSeconds : 0.0003
# AvgSignalSeconds   : 0.0002
#
# SqlInstance        : localhost\dev2017
# Category           : Preemptive
# WaitType           : PREEMPTIVE_OS_GETVOLUMEPATHNAME
# Percentage         : 1.28
# WaitCount          : 79438
# WaitSeconds        : 91.19
# ResourceSeconds    : 91.19
# SignalSeconds      : 0.00
# AvgWaitSeconds     : 0.0011
# AvgResourceSeconds : 0.0011
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2017
# Category           : Preemptive
# WaitType           : PREEMPTIVE_OS_GETFILEATTRIBUTES
# Percentage         : 1.13
# WaitCount          : 662689
# WaitSeconds        : 80.72
# ResourceSeconds    : 80.72
# SignalSeconds      : 0.00
# AvgWaitSeconds     : 0.0001
# AvgResourceSeconds : 0.0001
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2017
# Category           :
# WaitType           : CHECK_TABLES_INITIALIZATION
# Percentage         : 0.92
# WaitCount          : 1316
# WaitSeconds        : 65.52
# ResourceSeconds    : 65.40
# SignalSeconds      : 0.13
# AvgWaitSeconds     : 0.0498
# AvgResourceSeconds : 0.0497
# AvgSignalSeconds   : 0.0001
#
# SqlInstance        : localhost\dev2016
# Category           : Lock
# WaitType           : LCK_M_X
# Percentage         : 55.42
# WaitCount          : 44398
# WaitSeconds        : 754.63
# ResourceSeconds    : 749.60
# SignalSeconds      : 5.02
# AvgWaitSeconds     : 0.0170
# AvgResourceSeconds : 0.0169
# AvgSignalSeconds   : 0.0001
#
# SqlInstance        : localhost\dev2016
# Category           : Tran Log IO
# WaitType           : WRITELOG
# Percentage         : 9.31
# WaitCount          : 133430
# WaitSeconds        : 126.74
# ResourceSeconds    : 114.22
# SignalSeconds      : 12.52
# AvgWaitSeconds     : 0.0009
# AvgResourceSeconds : 0.0009
# AvgSignalSeconds   : 0.0001
#
# SqlInstance        : localhost\dev2016
# Category           : Worker Thread
# WaitType           : THREADPOOL
# Percentage         : 8.54
# WaitCount          : 124192
# WaitSeconds        : 116.34
# ResourceSeconds    : 116.32
# SignalSeconds      : 0.02
# AvgWaitSeconds     : 0.0009
# AvgResourceSeconds : 0.0009
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2016
# Category           : Other
# WaitType           : MSQL_XP
# Percentage         : 5.92
# WaitCount          : 39683
# WaitSeconds        : 80.56
# ResourceSeconds    : 80.56
# SignalSeconds      : 0.00
# AvgWaitSeconds     : 0.0020
# AvgResourceSeconds : 0.0020
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2016
# Category           : Compilation
# WaitType           : RESOURCE_SEMAPHORE_QUERY_COMPILE
# Percentage         : 4.55
# WaitCount          : 2289
# WaitSeconds        : 61.95
# ResourceSeconds    : 61.31
# SignalSeconds      : 0.64
# AvgWaitSeconds     : 0.0271
# AvgResourceSeconds : 0.0268
# AvgSignalSeconds   : 0.0003
#
# SqlInstance        : localhost\dev2016
# Category           : Lock
# WaitType           : LCK_M_S
# Percentage         : 2.81
# WaitCount          : 12
# WaitSeconds        : 38.21
# ResourceSeconds    : 38.21
# SignalSeconds      : 0.00
# AvgWaitSeconds     : 3.1840
# AvgResourceSeconds : 3.1838
# AvgSignalSeconds   : 0.0002
#
# SqlInstance        : localhost\dev2016
# Category           : CPU
# WaitType           : SOS_SCHEDULER_YIELD
# Percentage         : 1.94
# WaitCount          : 631927
# WaitSeconds        : 26.48
# ResourceSeconds    : 0.61
# SignalSeconds      : 25.87
# AvgWaitSeconds     : 0.0000
# AvgResourceSeconds : 0.0000
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2016
# Category           : Preemptive
# WaitType           : PREEMPTIVE_OS_AUTHZINITIALIZECONTEXTFROMSID
# Percentage         : 1.85
# WaitCount          : 6782
# WaitSeconds        : 25.15
# ResourceSeconds    : 25.15
# SignalSeconds      : 0.00
# AvgWaitSeconds     : 0.0037
# AvgResourceSeconds : 0.0037
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2016
# Category           : Network IO
# WaitType           : ASYNC_NETWORK_IO
# Percentage         : 1.60
# WaitCount          : 189582
# WaitSeconds        : 21.85
# ResourceSeconds    : 15.86
# SignalSeconds      : 5.98
# AvgWaitSeconds     : 0.0001
# AvgResourceSeconds : 0.0001
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2016
# Category           : Preemptive
# WaitType           : PREEMPTIVE_OS_CRYPTACQUIRECONTEXT
# Percentage         : 1.59
# WaitCount          : 56376
# WaitSeconds        : 21.60
# ResourceSeconds    : 21.60
# SignalSeconds      : 0.00
# AvgWaitSeconds     : 0.0004
# AvgResourceSeconds : 0.0004
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2016
# Category           : Buffer IO
# WaitType           : PAGEIOLATCH_SH
# Percentage         : 1.11
# WaitCount          : 17273
# WaitSeconds        : 15.11
# ResourceSeconds    : 14.94
# SignalSeconds      : 0.18
# AvgWaitSeconds     : 0.0009
# AvgResourceSeconds : 0.0009
# AvgSignalSeconds   : 0.0000
#
# SqlInstance        : localhost\dev2016
# Category           : Preemptive
# WaitType           : PREEMPTIVE_OS_AUTHORIZATIONOPS
# Percentage         : 0.85
# WaitCount          : 68700
# WaitSeconds        : 11.62
# ResourceSeconds    : 11.62
# SignalSeconds      : 0.00
# AvgWaitSeconds     : 0.0002
# AvgResourceSeconds : 0.0002
# AvgSignalSeconds   : 0.0000

# %% [markdown]
# # Chapter 9

# %% [markdown]
# # Rename Worksheets and Zip Spreadsheet

# %%
$rundate = Get-Date -Format yyyyMMdd_HHmmss;
$workbook = "C:\Users\fgill\Documents\GitHub\healthcheck\JupyterNotebooks\healthcheck.xlsx";
$newworkbook = "C:\Users\fgill\Documents\GitHub\healthcheck\JupyterNotebooks\healthcheck_$rundate.xlsx";
$worksheets = "Sheet1", "Sheet2", "Sheet3", "Sheet4","Sheet5", "Sheet6", "Sheet7", "Sheet8";

$newworksheets = "DatabaseInfo", "VLFInfo", "VlfByStatus", "DateFileInfo", "LogFileInfo", "Configuration", "AgentAlerts", "WaitStats";
$newindex = 0;

foreach($worksheet in $worksheets)
{
    Import-Excel -Path $workbook -WorksheetName $worksheet | Export-Excel -Path $newworkbook -WorksheetName $newworksheets[$newindex];
    $newindex += 1;
}

$archive = $newworkbook.Replace("xlsx","zip");

$compress = @{
  Path = $newworkbook
  CompressionLevel = "Fastest"
  DestinationPath = $archive;
}
Compress-Archive @compress;

Remove-Item -Path $workbook;
Remove-Item -Path $newworkbook;
